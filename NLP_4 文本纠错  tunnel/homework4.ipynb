# %% [markdown]
# 给出三个文件，词典库vocab.txt（任何不在词典中出现的词都认为是拼写错误），spell-errors.txt（给出正确单词与常见的拼写错误）与测试数据testdata.txt（1000个存在拼写错误的句子），利用bigram语言模型与Noisy Channel Model进行文本纠错训练。
# 步骤（每一步注释标注）：
#
# 一、读取词典库vocab.txt；
# 二、读取spell-errors.txt，计算概率p(错误的单词|正确的单词)；
# 三、选用nltk语料库movie_reviews，构建bigram语言模型；
# 四、对于词库里没有的词，取编辑距离为1和2，生成候选词集合；
# 五、读取testdata.txt，找出拼错词，生成候选词，并计算每个候选词的概率；
# 六、选出概率最高的候选词，作为修改词。
# 注：为便于计算，可采用似然对数，将概率乘积转化为求和。注意平滑。
# 输出：对每个句子，输出句子编号，拼错词，修改词（若没有则输出False），候选词列表及概率。最后输出总拼错词数。
#
# **例如：**
# >第 1 句：
# protectionst protectionist\
# [('protectionist', -30.39215205399061), ('protection', -30.39215205399061), ('protectionism', -30.39215205399061), ('projections', -30.39215205399061)]\
# 第 2 句：\
# Tkyo's False\
# 第 3 句：\
# retaiation retaliation\
# [('retaliation', -29.442994506536245), ('relaxation', -30.829288867656135), ('reparation', -30.829288867656135), ('retardation', -30.829288867656135)] \
# 第 3 句：\
# Japan's Japanese\
# [('Japanese', -30.615365993495722), ('Japan', -30.615365993495722)]\
# ......
#
#
# ----

# %% [markdown]
# #### 第一步 : 读取词汇表

# %%
vocab = set([line.strip() for line in open('./data/hw4-data-vocab.txt')])
len(vocab)
# Out:
# 48227

# %% [markdown]
# ----
#
# #### 第二步：读取spell-errors.txt，统计p(错误的单词|正确的单词)的概率分布；

# %%
misspell_prob = {}

for line in open('./data/hw4-data-spell-errors.txt'):
    items = line.split(':')
    correct = items[0].strip()
    misspells = [item.strip() for item in items[1].split(',')]
    lenmisspells = 0 # 错误的拼写数量
    
    misspell_prob[correct] = {} # 建立correct对mistake的对应表
    cnt = 0 #有些后缀不为字母，表示出现多次
    for i in misspells:
        pro = 1.0
        if(i[len(i) - 1] >= '0' and i[len(i) - 1] <= '9'):
            pro *= eval(i[len(i) - 1]) 
            cnt += eval(i[len(i) - 1]) 
        else:
            cnt += 1
        misspell_prob[correct][i] = pro # 每个mistake对correct的出现频率
    for i in misspells:
        misspell_prob[correct][i] /= cnt # 除以总出现次数为出现概率
    #print(misspells, len(misspells), cnt)


# print(items)
misspell_prob
# Out:
# {'raining': {'rainning': 0.5, 'raning': 0.5},
#  'writings': {'writtings': 1.0},
#  'disparagingly': {'disparingly': 1.0},
#  'yellow': {'yello': 1.0},
#  'four': {'forer': 0.08333333333333333,
#   'fours': 0.08333333333333333,
#   'fuore': 0.08333333333333333,
#   'fore*5': 0.4166666666666667,
#   'for*4': 0.3333333333333333},
#  'woods': {'woodes': 1.0},
#  'hanging': {'haing': 1.0},
#  'aggression': {'agression': 1.0},
#  'looking': {'loking': 0.09090909090909091,
#   'begining': 0.09090909090909091,
#   'luing': 0.09090909090909091,
#   'look*2': 0.18181818181818182,
#   'locking': 0.09090909090909091,
#   'lucking': 0.09090909090909091,
#   'louk': 0.09090909090909091,
#   'looing': 0.09090909090909091,
#   'lookin': 0.09090909090909091,
#   'liking': 0.09090909090909091},
#  'eligible': {'eligble': 0.3333333333333333,
#   'elegable': 0.3333333333333333,
#   'eligable': 0.3333333333333333},
#  'electricity': {'electrisity': 0.25,
#   'electricty*2': 0.5,
#   'electrizity': 0.25},
#  'scold': {'schold': 0.5, 'skold': 0.5},
#  'adaptable': {'adabtable': 1.0},
#  'caned': {'canned': 0.5, 'cained': 0.5},
#  'immature': {'imature': 1.0},
#  "shouldn't": {'shoudln': 0.5, 'shouldnt': 0.5},
#  'swivel': {'swival': 1.0},
#  'appropriation': {'apropriation': 1.0},
#  'fur': {'furr': 0.5, 'fer': 0.5},
#  'stabbed': {'stabed': 1.0},
#  'Southwold': {'Suothwode': 1.0},
#  'disturb': {'distrebe': 0.5, 'desturb': 0.5},
#  'recollections': {'reclections': 0.5, 'recolections': 0.5},
#  'prize': {'prise': 0.5, 'prizer': 0.5},
#  'wednesday': {'wensday': 0.5, 'wedensday': 0.5},
#  'succession': {'sucession': 0.3333333333333333,
#   'sucesion': 0.3333333333333333,
#   'succesion': 0.3333333333333333},
#  'straight': {'strate': 0.2, 'strait': 0.2, 'staidght': 0.2, 'stright*2': 0.4},
#  'guardsmen': {'gards_men': 1.0},
#  'incremented': {'increented': 1.0},
#  'bacon': {'backen': 0.5, 'baken': 0.5},
#  'pulse': {'pluse': 1.0},
#  'elegant': {'elagent': 0.5, 'elligit': 0.5},
#  'second': {'secand': 0.16666666666666666,
#   'sexeon': 0.16666666666666666,
#   'secund': 0.16666666666666666,
#   'seconnd': 0.16666666666666666,
#   'seond': 0.16666666666666666,
#   'sekon': 0.16666666666666666},
#  'jamjar': {'jam_jar': 1.0},
#  'sailed': {'saled': 0.5, 'saild': 0.5},
#  'blouse': {'boludes': 1.0},
#  'thunder': {'thounder': 1.0},
#  'cooking': {'coking': 0.25,
#   'chocking': 0.25,
#   'kooking': 0.25,
#   'cocking': 0.25},
#  'fossil': {'fosscil': 1.0},
#  'increasing': {'incased': 0.023809523809523808,
#   'ingreesh_this': 0.023809523809523808,
#   'incresing': 0.023809523809523808,
#   'incriosing': 0.023809523809523808,
#   'increacing': 0.023809523809523808,
#   'incressing': 0.023809523809523808,
#   'increcing': 0.023809523809523808,
#   'ingeker': 0.023809523809523808,
#   'incrsin': 0.023809523809523808,
#   'inceasing': 0.023809523809523808,
#   'inceing': 0.023809523809523808,
#   'increase': 0.023809523809523808,
#   'insest': 0.023809523809523808,
#   'ingcresing': 0.023809523809523808,
#   'incuiseing': 0.023809523809523808,
#   'enchres': 0.023809523809523808,
#   'intheris': 0.023809523809523808,
#   'incesing': 0.023809523809523808,
#   'encreing': 0.023809523809523808,
#   'increesing': 0.023809523809523808,
#   'crace': 0.023809523809523808,
#   'encrising': 0.023809523809523808,
#   'increaseng': 0.023809523809523808,
#   'encressing': 0.023809523809523808,
#   'in_cresing': 0.023809523809523808,
#   'incrising': 0.023809523809523808,
#   'incersinges': 0.023809523809523808,
#   'changing': 0.023809523809523808,
#   'incesting': 0.023809523809523808,
#   'encreasing': 0.023809523809523808,
#   'crissing': 0.023809523809523808,
#   'incriasing': 0.023809523809523808,
#   'incsin': 0.023809523809523808,
#   'incing': 0.023809523809523808,
#   'increaseing': 0.023809523809523808,
#   'ingesing': 0.023809523809523808,
#   'imceasing': 0.023809523809523808,
#   'incristing': 0.023809523809523808,
#   'engressing': 0.023809523809523808,
#   'ingresin': 0.023809523809523808,
#   'incrase': 0.023809523809523808,
#   'encash': 0.023809523809523808},
#  'hero': {'heroe': 1.0},
#  'dahl': {'dael': 1.0},
#  'reporter': {'repoter': 0.125,
#   'rebarter': 0.125,
#   'reportor': 0.125,
#   'reproter': 0.125,
#   'reoporter': 0.125,
#   'repoted': 0.125,
#   'reporet': 0.125,
#   'peportery': 0.125},
#  'interrupting': {'interupting': 1.0},
#  'here': {'hiar': 0.029411764705882353,
#   'hare': 0.029411764705882353,
#   'hir': 0.029411764705882353,
#   'hair': 0.029411764705882353,
#   'haiw': 0.029411764705882353,
#   'liet': 0.029411764705882353,
#   'hreb': 0.029411764705882353,
#   'hah': 0.029411764705882353,
#   'her': 0.029411764705882353,
#   'hes': 0.029411764705882353,
#   'hiyr': 0.029411764705882353,
#   'there': 0.029411764705882353,
#   'three': 0.029411764705882353,
#   'hay': 0.029411764705882353,
#   'hea': 0.029411764705882353,
#   'herre': 0.029411764705882353,
#   'har': 0.029411764705882353,
#   'werr': 0.029411764705882353,
#   'head': 0.029411764705882353,
#   'heere': 0.029411764705882353,
#   'hera': 0.029411764705882353,
#   'heir': 0.029411764705882353,
#   'herd': 0.029411764705882353,
#   'heat': 0.029411764705882353,
#   'hear*11': 0.029411764705882353,
#   'handr': 0.029411764705882353,
#   'he': 0.029411764705882353,
#   'heer': 0.029411764705882353,
#   'hree': 0.029411764705882353,
#   'hire': 0.029411764705882353,
#   'thehe': 0.029411764705882353,
#   'hon': 0.029411764705882353,
#   'eate': 0.029411764705882353,
#   'poit': 0.029411764705882353},
#  'atoms': {'atom': 1.0},
#  'tape-recorded': {'tape_recorded': 1.0},
#  'shriek': {'shreik': 1.0},
#  'substance': {'substace': 1.0},
#  'elaborate': {'elaberate': 1.0},
#  'climbed': {'climb': 0.3333333333333333,
#   'climed': 0.3333333333333333,
#   'cimed': 0.3333333333333333},
#  'reports': {'reoprts': 1.0},
#  'controversy': {'contervercing': 0.013513513513513514,
#   'contervercuy': 0.013513513513513514,
#   'consonerse': 0.013513513513513514,
#   'counteversy': 0.013513513513513514,
#   'contravercy': 0.013513513513513514,
#   'contronversey': 0.013513513513513514,
#   'contiversey': 0.013513513513513514,
#   'countirversay': 0.013513513513513514,
#   'countrovesy': 0.013513513513513514,
#   'counterversing': 0.013513513513513514,
#   'comsversiary': 0.013513513513513514,
#   'controversave': 0.013513513513513514,
#   'contevesy': 0.013513513513513514,
#   'controveries': 0.013513513513513514,
#   'controversey': 0.013513513513513514,
#   'controvercy*2': 0.02702702702702703,
#   'contraversally': 0.013513513513513514,
#   'conteversy': 0.013513513513513514,
#   'comtevercy': 0.013513513513513514,
#   'controversaries': 0.013513513513513514,
#   'countufersey': 0.013513513513513514,
#   'controvarsey': 0.013513513513513514,
#   'conqouversing': 0.013513513513513514,
#   'contriversy': 0.013513513513513514,
#   'contraversey': 0.013513513513513514,
#   'controvesey': 0.013513513513513514,
#   'contraverse': 0.013513513513513514,
#   'countroversy': 0.013513513513513514,
#   'contraversy*2': 0.02702702702702703,
#   'constroversy': 0.013513513513513514,
#   'contruevency': 0.013513513513513514,
#   'connesary': 0.013513513513513514,
#   'contavercy': 0.013513513513513514,
#   'conversity': 0.013513513513513514,
#   'contretearsing': 0.013513513513513514,
#   'controvery': 0.013513513513513514,
#   'contrevy': 0.013513513513513514,
#   'controvsary': 0.013513513513513514,
#   'contiuvisy': 0.013513513513513514,
#   'controvese': 0.013513513513513514,
#   'contronersery': 0.013513513513513514,
#   'controvorsey': 0.013513513513513514,
#   'contravorsy': 0.013513513513513514,
#   'countrevercy': 0.013513513513513514,
#   'controvvesity': 0.013513513513513514,
#   'conterversy': 0.013513513513513514,
#   'conterverisy': 0.013513513513513514,
#   'contriversey': 0.013513513513513514,
#   'conterversty': 0.013513513513513514,
#   'contreversey': 0.013513513513513514,
#   'combtrovesy': 0.013513513513513514,
#   'conversey': 0.013513513513513514,
#   'contterversy': 0.013513513513513514,
#   'conturvesy': 0.013513513513513514,
#   'contrvercy': 0.013513513513513514,
#   'controvesy': 0.013513513513513514,
#   'coutueversy': 0.013513513513513514,
#   'controsory': 0.013513513513513514,
#   'contrefercing': 0.013513513513513514,
#   'counterners': 0.013513513513513514,
#   'controvercey': 0.013513513513513514,
#   'contowversie': 0.013513513513513514,
#   'controversay': 0.013513513513513514,
#   'conversation': 0.013513513513513514,
#   'controversary': 0.013513513513513514,
#   'contraversery': 0.013513513513513514,
#   'contreversy': 0.013513513513513514,
#   'controversie': 0.013513513513513514,
#   'contriverse': 0.013513513513513514,
#   'controversing': 0.013513513513513514,
#   'conterversay': 0.013513513513513514,
#   'contrusy': 0.013513513513513514},
#  'etiology': {'eitiology': 1.0},
#  'snowing': {'showing': 1.0},
#  'military': {'millitary': 0.3333333333333333,
#   'milatary': 0.3333333333333333,
#   'militery': 0.3333333333333333},
#  'cancellation': {'canselation': 0.029411764705882353,
#   'cassilation': 0.029411764705882353,
#   'canncelation': 0.029411764705882353,
#   'cancalation': 0.029411764705882353,
#   'consulation': 0.029411764705882353,
#   'cancelatin': 0.029411764705882353,
#   'canelation': 0.029411764705882353,
#   'cansallation': 0.029411764705882353,
#   'cansellation': 0.029411764705882353,
#   'cansilation': 0.029411764705882353,
#   'cancallation': 0.029411764705882353,
#   'canacellation': 0.029411764705882353,
#   'cannsulation': 0.029411764705882353,
#   'cansaltion': 0.029411764705882353,
#   'cancolateon': 0.029411764705882353,
#   'cansulation': 0.029411764705882353,
#   'consalation': 0.029411764705882353,
#   'canselution': 0.029411764705882353,
#   'cancilliation': 0.029411764705882353,
#   'canslation': 0.029411764705882353,
#   'cancillation': 0.029411764705882353,
#   'cancolation': 0.029411764705882353,
#   'cansalation': 0.029411764705882353,
#   'cancialation': 0.029411764705882353,
#   'cancatation': 0.029411764705882353,
#   'cancilation': 0.029411764705882353,
#   'canclation': 0.029411764705882353,
#   'cansolitation': 0.029411764705882353,
#   'cansolation': 0.029411764705882353,
#   'cancealation': 0.029411764705882353,
#   'cancilion': 0.029411764705882353,
#   'cancelation': 0.029411764705882353,
#   'chancelation': 0.029411764705882353,
#   'cansclitation': 0.029411764705882353},
#  'criticism': {'criticisim': 0.010869565217391304,
#   'critizeation': 0.010869565217391304,
#   'criticizem': 0.010869565217391304,
#   'coritisumn': 0.010869565217391304,
#   'critisicsm': 0.010869565217391304,
#   'criticisam': 0.010869565217391304,
#   'critisizem': 0.010869565217391304,
#   'critisium': 0.010869565217391304,
#   'critizition': 0.010869565217391304,
#   'critisisem': 0.010869565217391304,
#   'crisisem': 0.010869565217391304,
#   'critiscism': 0.010869565217391304,
#   'critisisum': 0.010869565217391304,
#   'critigism': 0.010869565217391304,
#   'critisum': 0.010869565217391304,
#   'critizim': 0.010869565217391304,
#   'certsemus': 0.010869565217391304,
#   'griticism': 0.010869565217391304,
#   'critizm': 0.010869565217391304,
#   'critizesum': 0.010869565217391304,
#   'cretism': 0.010869565217391304,
#   'crisizum': 0.010869565217391304,
#   'critisima': 0.010869565217391304,
#   'critizam': 0.010869565217391304,
#   'critisizum': 0.010869565217391304,
#   'critisiem': 0.010869565217391304,
#   'criticisiom': 0.010869565217391304,
#   'critisim': 0.010869565217391304,
#   'critizizem': 0.010869565217391304,
#   'critisizm': 0.010869565217391304,
#   'critisism*2': 0.021739130434782608,
#   'critisiciam': 0.010869565217391304,
#   'crictism': 0.010869565217391304,
#   'critizium': 0.010869565217391304,
#   'critisicm': 0.010869565217391304,
#   'crittissisam': 0.010869565217391304,
#   'criticiz': 0.010869565217391304,
#   'criticisium': 0.010869565217391304,
#   'critisyum': 0.010869565217391304,
#   'critisicem': 0.010869565217391304,
#   'critissam': 0.010869565217391304,
#   'criticiam': 0.010869565217391304,
#   'citisum': 0.010869565217391304,
#   'critizom': 0.010869565217391304,
#   'critiszm': 0.010869565217391304,
#   'criticise': 0.010869565217391304,
#   'critisisim': 0.010869565217391304,
#   'criticisum': 0.010869565217391304,
#   'criticizement': 0.010869565217391304,
#   'cridictcisim': 0.010869565217391304,
#   'criticisms': 0.010869565217391304,
#   'critisizime': 0.010869565217391304,
#   'criticisem': 0.010869565217391304,
#   'critisizim': 0.010869565217391304,
#   'critisision': 0.010869565217391304,
#   'critizism': 0.010869565217391304,
#   'crisiam': 0.010869565217391304,
#   'critisisam': 0.010869565217391304,
#   'criticsm': 0.010869565217391304,
#   'critisiam': 0.010869565217391304,
#   'criticizasm': 0.010869565217391304,
#   'critizum': 0.010869565217391304,
#   'criticizin': 0.010869565217391304,
#   'critizisum': 0.010869565217391304,
#   'critizen': 0.010869565217391304,
#   'critizem': 0.010869565217391304,
#   'critzen': 0.010869565217391304,
#   'cretacesum': 0.010869565217391304,
#   'courtesisum': 0.010869565217391304,
#   'critisym': 0.010869565217391304,
#   'cretisism': 0.010869565217391304,
#   'critizisim': 0.010869565217391304,
#   'criticitisem': 0.010869565217391304,
#   'crypticism': 0.010869565217391304,
#   'critizizam': 0.010869565217391304,
#   'critisesimon': 0.010869565217391304,
#   'critisem': 0.010869565217391304,
#   'critcism': 0.010869565217391304,
#   'criticem': 0.010869565217391304,
#   'criciticisms': 0.010869565217391304,
#   'cirtissimum': 0.010869565217391304,
#   'critici': 0.010869565217391304,
#   'criticm': 0.010869565217391304,
#   'critism': 0.010869565217391304,
#   'critision': 0.010869565217391304,
#   'crytisym': 0.010869565217391304,
#   'criticizm': 0.010869565217391304,
#   'courtisum': 0.010869565217391304,
#   'critisizen': 0.010869565217391304,
#   'critizitim': 0.010869565217391304,
#   'criticum': 0.010869565217391304},
#  'golden': {'goldin': 0.5, 'gloden': 0.5},
#  'sines': {'sinse': 1.0},
#  'divide': {'devide*2': 0.6666666666666666, 'divid': 0.3333333333333333},
#  'subtracts': {'substracts': 1.0},
#  'there_had': {'therad': 1.0},
#  'criticise': {'critisize': 1.0},
#  'sweetest': {'sweetes': 1.0},
#  'explained': {'explan': 0.027777777777777776,
#   'epled': 0.027777777777777776,
#   'exclimed': 0.027777777777777776,
#   'exeplande': 0.027777777777777776,
#   'explainded': 0.027777777777777776,
#   'ecspained': 0.027777777777777776,
#   'explard': 0.027777777777777776,
#   'exslanded': 0.027777777777777776,
#   'explanned': 0.027777777777777776,
#   'expanel': 0.027777777777777776,
#   'exesnd': 0.027777777777777776,
#   'expaned': 0.027777777777777776,
#   'exlpand': 0.027777777777777776,
#   'explain': 0.027777777777777776,
#   'explaind': 0.027777777777777776,
#   'eixplaned': 0.027777777777777776,
#   'exsplaned': 0.027777777777777776,
#   'eplained': 0.027777777777777776,
#   'exsplain': 0.027777777777777776,
#   'explaid': 0.027777777777777776,
#   'explaned': 0.027777777777777776,
#   'epland': 0.027777777777777776,
#   'expand': 0.027777777777777776,
#   'extamed': 0.027777777777777776,
#   'explant': 0.027777777777777776,
#   'ekplaned': 0.027777777777777776,
#   'expaine': 0.027777777777777776,
#   'exploxen': 0.027777777777777776,
#   'explairded': 0.027777777777777776,
#   'explane': 0.027777777777777776,
#   'expland': 0.027777777777777776,
#   'expent': 0.027777777777777776,
#   'exclaimed': 0.027777777777777776,
#   'exprand': 0.027777777777777776,
#   'exple': 0.027777777777777776,
#   'exclamed': 0.027777777777777776},
#  'brought': {'broght': 0.1111111111111111,
#   'broug': 0.1111111111111111,
#   'brough*2': 0.2222222222222222,
#   'brot': 0.1111111111111111,
#   'bught': 0.1111111111111111,
#   'brort': 0.1111111111111111,
#   'brougth': 0.1111111111111111,
#   'bought': 0.1111111111111111},
#  'remnant': {'reminent': 1.0},
#  'sizeable': {'sizable': 1.0},
#  'opponents': {'oppenerts': 1.0},
#  'spoke': {'spoak': 0.25, 'spock': 0.25, 'spok': 0.25, 'spook': 0.25},
#  'browse': {'bbrose': 1.0},
#  'music': {'muic': 0.5, 'muice': 0.5},
#  'telegraph': {'telagraph': 1.0},
#  'strike': {'stricke': 0.3333333333333333,
#   'sricke': 0.3333333333333333,
#   'strick': 0.3333333333333333},
#  'until': {'intal': 0.08333333333333333,
#   'untill*9': 0.75,
#   'uatill': 0.08333333333333333,
#   'untl': 0.08333333333333333},
#  'holy': {'wholy': 0.3333333333333333,
#   'holly': 0.3333333333333333,
#   'holey': 0.3333333333333333},
#  'relax': {'relacks': 1.0},
#  'successful': {'sucksesful': 0.012345679012345678,
#   'sucsselful': 0.012345679012345678,
#   'seckesful': 0.012345679012345678,
#   'sacsesful': 0.012345679012345678,
#   'sussecful': 0.012345679012345678,
#   'sucsesfult': 0.012345679012345678,
#   'sususful': 0.012345679012345678,
#   'seccesful': 0.012345679012345678,
#   'suxsesful': 0.012345679012345678,
#   'sucsful': 0.012345679012345678,
#   'sussfull': 0.012345679012345678,
#   'sucsesfull': 0.012345679012345678,
#   'sucssuful': 0.012345679012345678,
#   'sucsessful': 0.012345679012345678,
#   'siccesefull': 0.012345679012345678,
#   'sursenful': 0.012345679012345678,
#   'suxsusful': 0.012345679012345678,
#   'suksesfull': 0.012345679012345678,
#   'succful': 0.012345679012345678,
#   'successfull*2': 0.024691358024691357,
#   'sucessful': 0.012345679012345678,
#   'succesfull': 0.012345679012345678,
#   'secsecfuly': 0.012345679012345678,
#   'sucessfull*2': 0.024691358024691357,
#   'successeful': 0.012345679012345678,
#   'suxcessful': 0.012345679012345678,
#   'sesesful': 0.012345679012345678,
#   'scucfull': 0.012345679012345678,
#   'succesfel': 0.012345679012345678,
#   'sexcful': 0.012345679012345678,
#   'suckessful': 0.012345679012345678,
#   'succsesfull': 0.012345679012345678,
#   'secessful': 0.012345679012345678,
#   'sucfull': 0.012345679012345678,
#   'successfuly': 0.012345679012345678,
#   'seceful': 0.012345679012345678,
#   'suckcesfull': 0.012345679012345678,
#   'surseful': 0.012345679012345678,
#   'saseful': 0.012345679012345678,
#   'sucksfull': 0.012345679012345678,
#   'susesful': 0.012345679012345678,
#   'surou': 0.012345679012345678,
#   'sucefull': 0.012345679012345678,
#   'succeful': 0.012345679012345678,
#   'sucsfully': 0.012345679012345678,
#   'sexself': 0.012345679012345678,
#   'succesfully': 0.012345679012345678,
#   'uscsful': 0.012345679012345678,
#   'sucesful*2': 0.024691358024691357,
#   'sucseful': 0.012345679012345678,
#   'succfull': 0.012345679012345678,
#   'succusfull': 0.012345679012345678,
#   'secsecful': 0.012345679012345678,
#   'sucksesfull': 0.012345679012345678,
#   'suchsefull': 0.012345679012345678,
#   'sacksesful': 0.012345679012345678,
#   'scuksefuly': 0.012345679012345678,
#   'succesful*2': 0.024691358024691357,
#   'sucsefully': 0.012345679012345678,
#   'secseful': 0.012345679012345678,
#   'succeshful': 0.012345679012345678,
#   'sucsessfull': 0.012345679012345678,
#   'suchesbull': 0.012345679012345678,
#   'sucsesfle': 0.012345679012345678,
#   'suxsefal': 0.012345679012345678,
#   'sucsesful': 0.012345679012345678,
#   'suceseful': 0.012345679012345678,
#   'sukseful': 0.012345679012345678,
#   'succsessful': 0.012345679012345678,
#   'succsefull': 0.012345679012345678,
#   'suskfull': 0.012345679012345678,
#   'suceful': 0.012345679012345678,
#   'sucesfull': 0.012345679012345678,
#   'succsesful': 0.012345679012345678,
#   'sucesfful': 0.012345679012345678,
#   'sussefull': 0.012345679012345678,
#   'secsesful': 0.012345679012345678},
#  'hurt': {'heart': 0.2, 'hert*3': 0.6, 'hearte': 0.2},
#  'glass': {'glas': 0.5, 'glars': 0.5},
#  'reversible': {'reversable': 1.0},
#  'tying': {'tieing': 1.0},
#  'hole': {'hol': 0.3333333333333333,
#   'hold': 0.3333333333333333,
#   'holler': 0.3333333333333333},
#  'hold': {'hod': 0.5, 'holed': 0.5},
#  'circumstances': {'circumstaces': 1.0},
#  'locked': {'lock': 0.3333333333333333,
#   'lockEd': 0.3333333333333333,
#   'lockd': 0.3333333333333333},
#  'pursue': {'persue*3': 0.75, 'presue': 0.25},
#  'accomplishment': {'acomplishment': 1.0},
#  'apologetics': {'apolegetics': 1.0},
#  'locker': {'loker': 1.0},
#  'example': {'exemple': 0.25,
#   'exmaple': 0.25,
#   'exsample': 0.25,
#   'exmple': 0.25},
#  'household': {'houshe': 1.0},
#  'artillery': {'artillary': 1.0},
#  'organized': {'oranised': 0.5, 'orginized': 0.5},
#  'caution': {'causion': 0.5, 'cortion': 0.5},
#  'want': {'wont': 0.03333333333333333,
#   'wants': 0.03333333333333333,
#   'what': 0.03333333333333333,
#   'mant': 0.03333333333333333,
#   'whant*7': 0.23333333333333334,
#   'wand': 0.03333333333333333,
#   'watn': 0.03333333333333333,
#   "whan't*2": 0.06666666666666667,
#   'woth': 0.03333333333333333,
#   'wnat': 0.03333333333333333,
#   'whon': 0.03333333333333333,
#   'whont*5': 0.16666666666666666,
#   "won't*4": 0.13333333333333333,
#   'wernt': 0.03333333333333333,
#   'went': 0.03333333333333333,
#   'wat': 0.03333333333333333},
#  'preferably': {'preferrably': 1.0},
#  'hog': {'hag': 1.0},
#  'hoe': {'how': 0.5, 'ho': 0.5},
#  'complaining': {'complanig': 1.0},
#  'travel': {'travle': 0.3333333333333333,
#   'travill': 0.3333333333333333,
#   'travell': 0.3333333333333333},
#  'damage': {'damaged': 0.08333333333333333,
#   'damadge': 0.08333333333333333,
#   'Dameage': 0.08333333333333333,
#   'damge': 0.08333333333333333,
#   'Damage': 0.08333333333333333,
#   'dammage': 0.08333333333333333,
#   'damuge': 0.08333333333333333,
#   'damagage': 0.08333333333333333,
#   'damaze': 0.08333333333333333,
#   'danage': 0.08333333333333333,
#   'damnage': 0.08333333333333333,
#   'damgous': 0.08333333333333333},
#  'machine': {'mecichly': 0.029411764705882353,
#   'merchen': 0.029411764705882353,
#   'meshien': 0.029411764705882353,
#   'michin': 0.029411764705882353,
#   'minhen': 0.029411764705882353,
#   'machane': 0.029411764705882353,
#   'merchain': 0.029411764705882353,
#   'mishn': 0.029411764705882353,
#   'maechen': 0.029411764705882353,
#   'mosien': 0.029411764705882353,
#   'moter': 0.029411764705882353,
#   'masir': 0.029411764705882353,
#   'matchine': 0.029411764705882353,
#   'macine': 0.029411764705882353,
#   'mashen': 0.029411764705882353,
#   'machiene': 0.029411764705882353,
#   'merchine': 0.029411764705882353,
#   'mishing': 0.029411764705882353,
#   'meirshin': 0.029411764705882353,
#   'mechine': 0.029411764705882353,
#   'micshine': 0.029411764705882353,
#   'mashin': 0.029411764705882353,
#   'mashine': 0.029411764705882353,
#   'manchine': 0.029411764705882353,
#   'mching': 0.029411764705882353,
#   'mesen': 0.029411764705882353,
#   'macien': 0.029411764705882353,
#   'muchien': 0.029411764705882353,
#   'mrosin': 0.029411764705882353,
#   'machian': 0.029411764705882353,
#   'masgen': 0.029411764705882353,
#   'mshin': 0.029411764705882353,
#   'machein': 0.029411764705882353,
#   'macheine': 0.029411764705882353},
#  'how': {'hou': 0.5, 'haw': 0.5},
#  'hot': {'thot': 0.125,
#   'rat': 0.125,
#   'hoot': 0.125,
#   'hala': 0.125,
#   'hote': 0.125,
#   'aht': 0.125,
#   'tert': 0.125,
#   'hat': 0.125},
#  'hop': {'hope': 1.0},
#  'cheetah': {'cheter*3': 1.0},
#  'preferable': {'preferrable': 1.0},
#  'fanaticism': {'fanatism': 1.0},
#  'vaccination': {'vacinnation': 1.0},
#  'beauty': {'beuty': 0.5, 'bueaty': 0.5},
#  'outlawed': {'oulawed': 1.0},
#  'wrong': {'wrang': 0.08333333333333333,
#   'wronge': 0.08333333333333333,
#   'ron': 0.08333333333333333,
#   'rong*3': 0.25,
#   'long': 0.08333333333333333,
#   'rog': 0.08333333333333333,
#   'wong': 0.08333333333333333,
#   'ronge': 0.08333333333333333,
#   'ro': 0.08333333333333333,
#   'worng': 0.08333333333333333},
#  'monolithic': {'monolite': 1.0},
#  'short-tempered': {'short_tempered': 1.0},
#  'effective': {'affective': 1.0},
#  'caisson': {'casion': 1.0},
#  'headquarters': {'headquoters': 1.0},
#  'season': {'seson': 1.0},
#  'signatories': {'signitories': 1.0},
#  'baggage': {'bagage': 1.0},
#  'orally': {'erally': 1.0},
#  'snowballs': {'snow_ball': 1.0},
#  'keeps': {'keep': 1.0},
#  'wind': {'win': 0.5, 'wid': 0.5},
#  'restriction': {'restrici': 1.0},
#  'dreamed': {'dremd': 1.0},
#  'misdemeanor': {'misdemenor': 0.5, 'misdameanor': 0.5},
#  'vary': {'varie': 1.0},
#  'sunshine': {'sunshin': 1.0},
#  'Nazareth': {'Nazereth': 1.0},
#  'fir': {'fur': 1.0},
#  'His': {"He's": 0.5, 'He': 0.5},
#  'fit': {'fite': 0.3333333333333333,
#   'fanit': 0.3333333333333333,
#   'fid': 0.3333333333333333},
#  'unforeseen': {'unforseen': 1.0},
#  'heretofore': {'heretofor': 1.0},
#  'secede': {'seceed': 1.0},
#  'survivors': {'survivers': 1.0},
#  'coach-load': {'coach_load': 1.0},
#  'distinguishing': {'distingishing': 1.0},
#  'insubstantial': {'insubstancial': 1.0},
#  'hidden': {'hidon': 1.0},
#  'Him': {'Im*2': 1.0},
#  'grievous': {'grievious': 1.0},
#  'interrupt': {'interupt*2': 1.0},
#  'blink': {'blnk': 1.0},
#  'eisenhower': {'eisenhhower': 1.0},
#  'scholar': {'scholer': 1.0},
#  'rumour': {'rumer': 0.5, 'rummer': 0.5},
#  'represents': {'repreents': 1.0},
#  'queues': {'ques': 1.0},
#  'shoelace': {'shoe_lace': 1.0},
#  'arrow': {'arow': 1.0},
#  'volcano': {'volcanoe': 1.0},
#  'dumpy': {'dunpty': 1.0},
#  'obdurate': {'obdirate': 1.0},
#  'preceded': {'preceeded': 1.0},
#  'financial': {'vaysuntte': 0.02127659574468085,
#   'fiynalle': 0.02127659574468085,
#   'finachle': 0.02127659574468085,
#   'finashall': 0.02127659574468085,
#   'finaancle': 0.02127659574468085,
#   'finatul': 0.02127659574468085,
#   'finantual': 0.02127659574468085,
#   'fintrol': 0.02127659574468085,
#   'fina': 0.02127659574468085,
#   'finnance': 0.02127659574468085,
#   'financhial': 0.02127659574468085,
#   'finanturel': 0.02127659574468085,
#   'finasle': 0.02127659574468085,
#   'finanshel': 0.02127659574468085,
#   'fineshel': 0.02127659574468085,
#   'financal': 0.02127659574468085,
#   'finnanle': 0.02127659574468085,
#   'finanial': 0.02127659574468085,
#   'financhel': 0.02127659574468085,
#   'firanshal': 0.02127659574468085,
#   'finachial': 0.02127659574468085,
#   'finashal': 0.02127659574468085,
#   'finenashsure': 0.02127659574468085,
#   'finatial': 0.02127659574468085,
#   'finane': 0.02127659574468085,
#   'fianation': 0.02127659574468085,
#   'finantial': 0.02127659574468085,
#   'finacwell': 0.02127659574468085,
#   'firnashal': 0.02127659574468085,
#   'fenecherue': 0.02127659574468085,
#   'finanshiol': 0.02127659574468085,
#   'financual': 0.02127659574468085,
#   'finachel': 0.02127659574468085,
#   'finasial': 0.02127659574468085,
#   'finacal': 0.02127659574468085,
#   'finatoil': 0.02127659574468085,
#   'finantal': 0.02127659574468085,
#   'finacial': 0.02127659574468085,
#   'finesha': 0.02127659574468085,
#   'fiancial': 0.02127659574468085,
#   'finashel': 0.02127659574468085,
#   'finatical': 0.02127659574468085,
#   'firnanshel': 0.02127659574468085,
#   'finanction': 0.02127659574468085,
#   'fineancal': 0.02127659574468085,
#   'finalshal': 0.02127659574468085,
#   'financhall': 0.02127659574468085},
#  'snakes': {'snaks': 0.5, 'snake': 0.5},
#  'archetypes': {'archtypes': 1.0},
#  'garment': {'garmet': 1.0},
#  'Teddy_boy': {'Teddoy*3': 0.75, 'Tedeboy': 0.25},
#  'spider': {'spiter': 1.0},
#  'turnip': {'turnup': 1.0},
#  'precedes': {'preceeds': 1.0},
#  'fortnight': {'fort_night': 1.0},
#  'laboratory': {'labory': 0.030303030303030304,
#   'labotorey': 0.030303030303030304,
#   'laboraty': 0.030303030303030304,
#   'labritory': 0.030303030303030304,
#   'labroratory': 0.030303030303030304,
#   'lavatory': 0.030303030303030304,
#   'labortory': 0.030303030303030304,
#   'labertory': 0.030303030303030304,
#   'labrotory': 0.030303030303030304,
#   'laboatory': 0.030303030303030304,
#   'libertory': 0.030303030303030304,
#   'labatory': 0.030303030303030304,
#   'laboretory': 0.030303030303030304,
#   'labratory*2': 0.06060606060606061,
#   'laberotary': 0.030303030303030304,
#   'labitory': 0.030303030303030304,
#   'labaratory': 0.030303030303030304,
#   'labetory': 0.030303030303030304,
#   'lavoratory': 0.030303030303030304,
#   'elatory': 0.030303030303030304,
#   'lab': 0.030303030303030304,
#   'laveratory': 0.030303030303030304,
#   'labartory': 0.030303030303030304,
#   'labortary': 0.030303030303030304,
#   'laboritory': 0.030303030303030304,
#   'labority': 0.030303030303030304,
#   'laborotory': 0.030303030303030304,
#   'labarotory': 0.030303030303030304,
#   'lavortory': 0.030303030303030304,
#   'laborbtory': 0.030303030303030304,
#   'laberatory': 0.030303030303030304,
#   'lavratory': 0.030303030303030304},
#  'ring': {'rings': 1.0},
#  'whip': {'wip': 1.0},
#  'excepting': {'exepting': 1.0},
#  'encourage': {'incourage': 0.25,
#   'encorage': 0.25,
#   'encourge': 0.25,
#   'encourg': 0.25},
#  'engineer': {'engeneer': 0.3333333333333333,
#   'engieneer': 0.3333333333333333,
#   'enginer': 0.3333333333333333},
#  'foundation': {'foundition': 0.5, 'fondation': 0.5},
#  'inhabitants': {'habitants': 1.0},
#  'assured': {'asured': 1.0},
#  'threatened': {'thretened': 1.0},
#  'surveys': {'survays': 0.5, 'servays': 0.5},
#  'grapes': {'graps': 1.0},
#  'sheet': {'sheat*2': 0.6666666666666666, 'shet': 0.3333333333333333},
#  'estimate': {'estamate': 1.0},
#  'knit': {'knitt': 0.3333333333333333,
#   'niet': 0.3333333333333333,
#   'nit': 0.3333333333333333},
#  'universally': {'universaly': 1.0},
#  'enormous': {'enormas': 0.25,
#   'emerous': 0.25,
#   'enourmous': 0.25,
#   'enormus': 0.25},
#  'ate': {'et': 0.16666666666666666,
#   'aet': 0.16666666666666666,
#   'eat*3': 0.5,
#   'ete': 0.16666666666666666},
#  'scruff': {'scruf': 1.0},
#  'reprimanded': {'repremanded': 1.0},
#  'dinner-hour': {'dinner_hour': 1.0},
#  "today's": {'todays': 1.0},
#  'sallies': {'sally': 1.0},
#  'wash': {'wach': 0.5, 'wosh': 0.5},
#  'instruct': {'instruck': 1.0},
#  'customization': {'custamisation': 1.0},
#  'bitten': {'biten': 1.0},
#  'rhododendron': {'rhododrendon': 1.0},
#  'basketball': {'baskball': 0.07692307692307693,
#   'Basketball': 0.07692307692307693,
#   'basketbale': 0.07692307692307693,
#   'Basket-Ball': 0.07692307692307693,
#   'baskt-ball': 0.07692307692307693,
#   'baskeball': 0.07692307692307693,
#   'basket-ball': 0.07692307692307693,
#   'bascketball': 0.07692307692307693,
#   'basket-Ball': 0.07692307692307693,
#   'baskitball': 0.07692307692307693,
#   'bascket-ball': 0.07692307692307693,
#   'Basket_ball': 0.07692307692307693,
#   'bastestball': 0.07692307692307693},
#  'service': {'cirvice': 0.25,
#   'survice': 0.25,
#   'servise': 0.25,
#   'servace': 0.25},
#  'similarly': {'similarily*2': 1.0},
#  'engagement': {'enagement': 1.0},
#  'needed': {'need': 0.25, 'nedded': 0.25, 'mided': 0.25, 'neaded': 0.25},
#  'perturbations': {'pertubations': 1.0},
#  'master': {'mater': 1.0},
#  'architect': {'archetect': 1.0},
#  'listen': {'lisen': 0.16666666666666666,
#   'lesson': 0.16666666666666666,
#   'lisn': 0.16666666666666666,
#   'leasten': 0.16666666666666666,
#   'listern*2': 0.3333333333333333},
#  'geneva': {'geniva': 1.0},
#  'snooty': {'snoty': 1.0},
#  'predictable': {'predicable': 1.0},
#  'crawl': {'crol': 0.5, 'crall': 0.5},
#  'positively': {'positivly': 1.0},
#  'sidereal': {'sedereal': 0.5, 'sideral': 0.5},
#  'showed': {'showd': 0.5, 'shod': 0.5},
#  'approximations': {'appoximations': 1.0},
#  'tree': {'treee': 0.25, 'tre': 0.25, 'three': 0.25, 'tee': 0.25},
#  'omnivorous': {'omniverous': 1.0},
#  'project': {'progetr': 0.058823529411764705,
#   'proget': 0.058823529411764705,
#   'prget': 0.058823529411764705,
#   'pojert': 0.058823529411764705,
#   'projer': 0.058823529411764705,
#   'prung': 0.058823529411764705,
#   'commet': 0.058823529411764705,
#   'pgett': 0.058823529411764705,
#   'projet': 0.058823529411764705,
#   'projoc': 0.058823529411764705,
#   'progect': 0.058823529411764705,
#   'porait': 0.058823529411764705,
#   'poujent': 0.058823529411764705,
#   'projent': 0.058823529411764705,
#   'projexty': 0.058823529411764705,
#   'poragced': 0.058823529411764705,
#   'porcet': 0.058823529411764705},
#  'pneumonia': {'nuemonia': 0.00909090909090909,
#   'memonia': 0.00909090909090909,
#   'pnenonia': 0.00909090909090909,
#   'pnuemonia': 0.00909090909090909,
#   'phneumonia': 0.00909090909090909,
#   'ammonia': 0.00909090909090909,
#   'pnmonia': 0.00909090909090909,
#   'phemonia': 0.00909090909090909,
#   'pneumaine': 0.00909090909090909,
#   'phneomia': 0.00909090909090909,
#   'phenomia': 0.00909090909090909,
#   'pnemounia': 0.00909090909090909,
#   'nomina': 0.00909090909090909,
#   'phenominia': 0.00909090909090909,
#   'phneomina': 0.00909090909090909,
#   'pnenumoia': 0.00909090909090909,
#   'phewmonia': 0.00909090909090909,
#   'pneimonia': 0.00909090909090909,
#   'newmonia': 0.00909090909090909,
#   'amnonnia': 0.00909090909090909,
#   'phemonuia': 0.00909090909090909,
#   'pneunomia': 0.00909090909090909,
#   'amomea': 0.00909090909090909,
#   'phenioma': 0.00909090909090909,
#   'nephonia': 0.00909090909090909,
#   'pheunomia': 0.00909090909090909,
#   'phenomenia': 0.00909090909090909,
#   'phunmonia': 0.00909090909090909,
#   'phnomeia': 0.00909090909090909,
#   'peneumia': 0.00909090909090909,
#   'phomonia': 0.00909090909090909,
#   'phumonia': 0.00909090909090909,
#   'pnumonia': 0.00909090909090909,
#   'pheuphmonia': 0.00909090909090909,
#   'pnemoninia': 0.00909090909090909,
#   'pneunonia': 0.00909090909090909,
#   'phonimonu': 0.00909090909090909,
#   'phuemonia': 0.00909090909090909,
#   'ponuime': 0.00909090909090909,
#   'anumonian': 0.00909090909090909,
#   'anomina': 0.00909090909090909,
#   'phnomia': 0.00909090909090909,
#   'pneaumonia': 0.00909090909090909,
#   'phenoumonia': 0.00909090909090909,
#   'Phnumonia': 0.00909090909090909,
#   'pnomonia': 0.00909090909090909,
#   'phenoumina': 0.00909090909090909,
#   'penmonia': 0.00909090909090909,
#   'phenoumia': 0.00909090909090909,
#   'newmony': 0.00909090909090909,
#   'phenumia': 0.00909090909090909,
#   'pnueounia': 0.00909090909090909,
#   'phenimonia': 0.00909090909090909,
#   'numonia': 0.00909090909090909,
#   'penominia': 0.00909090909090909,
#   'phnumonia': 0.00909090909090909,
#   'pounia': 0.00909090909090909,
#   'puemonia': 0.00909090909090909,
#   'pnemonia': 0.00909090909090909,
#   'pnenomionia': 0.00909090909090909,
#   'phenomu': 0.00909090909090909,
#   'pneumia': 0.00909090909090909,
#   'pneumnia': 0.00909090909090909,
#   'pheomena': 0.00909090909090909,
#   'pnenonea': 0.00909090909090909,
#   'phemomina': 0.00909090909090909,
#   'phenomnia': 0.00909090909090909,
#   'anonianu': 0.00909090909090909,
#   'phmoinia': 0.00909090909090909,
#   'pneurminu': 0.00909090909090909,
#   'phnemona': 0.00909090909090909,
#   'pheunomina': 0.00909090909090909,
#   'Pheumonia': 0.00909090909090909,
#   'phemonuime': 0.00909090909090909,
#   'Pneumonia': 0.00909090909090909,
#   'phnenimonia': 0.00909090909090909,
#   'pheumonia': 0.00909090909090909,
#   'phnuemonia': 0.00909090909090909,
#   'namoia': 0.00909090909090909,
#   'nephenoma': 0.00909090909090909,
#   'namouny': 0.00909090909090909,
#   'pheneumonia': 0.00909090909090909,
#   'pnumonenia': 0.00909090909090909,
#   'numonuia': 0.00909090909090909,
#   'pneumunia': 0.00909090909090909,
#   'nemonia': 0.00909090909090909,
#   'pnumonea': 0.00909090909090909,
#   'phunemonia': 0.00909090909090909,
#   'peunmonia': 0.00909090909090909,
#   'pneumphia': 0.00909090909090909,
#   'neumonia': 0.00909090909090909,
#   'pnenomia': 0.00909090909090909,
#   'knemonu': 0.00909090909090909,
#   'phnemonia': 0.00909090909090909,
#   'phnemounia': 0.00909090909090909,
#   'pnumeia': 0.00909090909090909,
#   'pneomonia': 0.00909090909090909,
#   'peunomia': 0.00909090909090909,
#   'phomoniow': 0.00909090909090909,
#   'Phonia': 0.00909090909090909,
#   'demondia': 0.00909090909090909,
#   'phmeuaina': 0.00909090909090909,
#   'phenemonia': 0.00909090909090909,
#   'numoia': 0.00909090909090909,
#   'remote': 0.00909090909090909,
#   'penumonia': 0.00909090909090909,
#   'munonia': 0.00909090909090909,
#   'phenumonia': 0.00909090909090909,
#   'pneuammia': 0.00909090909090909,
#   'amonia': 0.00909090909090909},
#  'idle': {'idel': 0.5, 'ide': 0.5},
#  'readjusted': {'reajusted': 1.0},
#  'seminary': {'seminery': 1.0},
#  'feeling': {'feling': 0.3333333333333333,
#   'felling': 0.3333333333333333,
#   'fealing': 0.3333333333333333},
#  'acquisition': {'aquisistion': 0.5, 'aquisition': 0.5},
#  'a_lot': {'lot': 0.25, 'alote': 0.25, 'alot*2': 0.5},
#  "to-day's": {'two_days': 0.14285714285714285,
#   'todays': 0.14285714285714285,
#   "todays'": 0.14285714285714285,
#   'to-days': 0.14285714285714285,
#   "today's": 0.14285714285714285,
#   'todaies': 0.14285714285714285,
#   'to_days': 0.14285714285714285},
#  'runner': {'runer': 1.0},
#  'dozen': {'doxen': 0.5, 'dosen': 0.5},
#  'wholesome': {'wholsome': 0.5, 'holesome': 0.5},
#  'courier': {'coururier': 1.0},
#  'responsible': {'resmoserbl': 0.2,
#   'responsable': 0.2,
#   'responcible': 0.2,
#   'reponsible': 0.2,
#   'reposable': 0.2},
#  'metallic': {'metalic': 1.0},
#  'asymmetric': {'assymmetric': 0.3333333333333333,
#   'asymetric': 0.3333333333333333,
#   'assymetric': 0.3333333333333333},
#  'Bang': {'Bankg*4': 1.0},
#  'causing': {'corsing': 0.5, 'coursing': 0.5},
#  'absorbed': {'asorbed': 0.5, 'abo': 0.5},
#  'amusing': {'amsing': 1.0},
#  'doors': {'doers': 0.5, 'dors': 0.5},
#  'responsibly': {'responsably': 1.0},
#  'Jones': {'Johnes': 1.0},
#  'committing': {'commiting*2': 0.5, 'comiting': 0.25, 'comitting': 0.25},
#  'shall': {'shale': 0.25, 'sall': 0.25, 'she': 0.25, 'shal': 0.25},
#  'object': {'objet': 1.0},
#  'a_little': {'alitl': 0.5, 'alittle': 0.5},
#  'mouth': {'moth': 1.0},
#  'letter': {'letre': 0.3333333333333333,
#   'teller': 0.3333333333333333,
#   'leter': 0.3333333333333333},
#  'conceded': {'conseived': 1.0},
#  'professor': {'professer': 0.2,
#   'profesor': 0.2,
#   'proffessor': 0.2,
#   'proffesor*2': 0.4},
#  'camp': {'kamp': 0.5, 'canp': 0.5},
#  'consummate': {'consumate': 1.0},
#  'nineteenth': {'ninteenth': 1.0},
#  'scream': {'scem': 0.3333333333333333,
#   'screem': 0.3333333333333333,
#   'screm': 0.3333333333333333},
#  'incomplete': {'incompleet': 0.5, 'incomplot': 0.5},
#  'marvel': {'marval': 1.0},
#  'polypropylene': {'polypropalene': 1.0},
#  'bomb': {'baumb': 0.1,
#   'bombe': 0.1,
#   'bome': 0.1,
#   'bomm': 0.1,
#   'bown': 0.1,
#   'bonod': 0.1,
#   'book': 0.1,
#   'bom': 0.1,
#   'bambe': 0.1,
#   'boom': 0.1},
#  'insects': {'insexs': 1.0},
#  'gauge': {'gadg': 0.027777777777777776,
#   'gape': 0.027777777777777776,
#   'garge': 0.027777777777777776,
#   'gare': 0.027777777777777776,
#   'gange': 0.027777777777777776,
#   'gang': 0.027777777777777776,
#   'tade': 0.027777777777777776,
#   'garer': 0.027777777777777776,
#   'gage': 0.027777777777777776,
#   'gach': 0.027777777777777776,
#   'gagde': 0.027777777777777776,
#   'cauge': 0.027777777777777776,
#   'gams': 0.027777777777777776,
#   'gadje': 0.027777777777777776,
#   'bergage': 0.027777777777777776,
#   'gradnang': 0.027777777777777776,
#   'gar': 0.027777777777777776,
#   'grage': 0.027777777777777776,
#   'gagech': 0.027777777777777776,
#   'garind': 0.027777777777777776,
#   'gag': 0.027777777777777776,
#   'gaog': 0.027777777777777776,
#   'cage': 0.027777777777777776,
#   'gargch': 0.027777777777777776,
#   'gadeg': 0.027777777777777776,
#   'rage': 0.027777777777777776,
#   'gaige': 0.027777777777777776,
#   'gade': 0.027777777777777776,
#   'gager': 0.027777777777777776,
#   'guage': 0.027777777777777776,
#   'gadge': 0.027777777777777776,
#   'ghase': 0.027777777777777776,
#   'guadge': 0.027777777777777776,
#   'gaoge': 0.027777777777777776,
#   'gaged': 0.027777777777777776,
#   'geich': 0.027777777777777776},
#  'lessons': {"lesson's": 0.14285714285714285,
#   'lessens': 0.14285714285714285,
#   'lesons': 0.14285714285714285,
#   'leasons': 0.14285714285714285,
#   'lessions': 0.14285714285714285,
#   'listerse': 0.14285714285714285,
#   'lesson': 0.14285714285714285},
#  'busy': {'bise': 0.25, 'buisy': 0.25, 'bussy': 0.25, 'bisy': 0.25},
#  'shuffling': {'shufarling': 1.0},
#  'than': {'then': 0.25, 'thna': 0.25, 'tahn': 0.25, 'that': 0.25},
#  'bush': {'buch*2': 1.0},
#  'touched': {'tesded': 0.02857142857142857,
#   'toure': 0.02857142857142857,
#   'cher': 0.02857142857142857,
#   'toched': 0.02857142857142857,
#   'theed': 0.02857142857142857,
#   'tost': 0.02857142857142857,
#   'tuched': 0.02857142857142857,
#   'tusted': 0.02857142857142857,
#   'toughed': 0.02857142857142857,
#   'tosh': 0.02857142857142857,
#   'touch': 0.02857142857142857,
#   'toached': 0.02857142857142857,
#   'tache': 0.02857142857142857,
#   'tucked': 0.02857142857142857,
#   'tust': 0.02857142857142857,
#   'tutet': 0.02857142857142857,
#   'toght': 0.02857142857142857,
#   'tuses': 0.02857142857142857,
#   'tush': 0.02857142857142857,
#   'tougched': 0.02857142857142857,
#   'tacah': 0.02857142857142857,
#   'tuchd': 0.02857142857142857,
#   'toch': 0.02857142857142857,
#   'toulched': 0.02857142857142857,
#   'turst': 0.02857142857142857,
#   'toutched': 0.02857142857142857,
#   'chuched': 0.02857142857142857,
#   'trosh': 0.02857142857142857,
#   'tiups': 0.02857142857142857,
#   'stuched': 0.02857142857142857,
#   'tuch': 0.02857142857142857,
#   'thach': 0.02857142857142857,
#   'touh': 0.02857142857142857,
#   'thucht': 0.02857142857142857,
#   'tashed': 0.02857142857142857},
#  'rich': {'rick': 1.0},
#  'rice': {'rise': 1.0},
#  'lady': {'lade': 0.25, 'ladey': 0.25, 'ladiy': 0.25, 'ladys': 0.25},
#  'plate': {'blate': 0.5, 'plat': 0.5},
#  'stammered': {'stamerd': 1.0},
#  'terrors': {'terrours': 1.0},
#  'foremost': {'formost': 1.0},
#  'pocket': {'poket': 1.0},
#  'foundries': {'foundaries': 1.0},
#  'cushion': {'cusion': 1.0},
#  'altogether': {'alltogether': 0.3333333333333333,
#   'atlogeher': 0.3333333333333333,
#   'all_together': 0.3333333333333333},
#  'jaguar': {'jagaur': 1.0},
#  'nicely': {'nicerly': 0.3333333333333333,
#   'nicly': 0.3333333333333333,
#   'micely': 0.3333333333333333},
#  'boarder': {'border': 1.0},
#  'patch': {'pacth': 1.0},
#  'blew': {'blow*3': 0.75, 'blue': 0.25},
#  'disaster': {'diaster': 1.0},
#  'fair': {'fare': 1.0},
#  'peripheral': {'periferal': 1.0},
#  'radius': {'radiuss': 0.5, 'radious': 0.5},
#  'fail': {'fale': 1.0},
#  'nocturnal': {'nocternal': 1.0},
#  'hammer': {'hamer': 1.0},
#  'best': {'bets': 0.05555555555555555,
#   'be': 0.05555555555555555,
#   'bast': 0.05555555555555555,
#   'dest': 0.05555555555555555,
#   'bass': 0.05555555555555555,
#   'beets': 0.05555555555555555,
#   'beat': 0.05555555555555555,
#   'bist': 0.05555555555555555,
#   'biwes': 0.05555555555555555,
#   'besh': 0.05555555555555555,
#   'besd': 0.05555555555555555,
#   'mest': 0.05555555555555555,
#   'beast': 0.05555555555555555,
#   'bettes': 0.05555555555555555,
#   'bister': 0.05555555555555555,
#   'bess': 0.05555555555555555,
#   'bes': 0.05555555555555555,
#   'bet': 0.05555555555555555},
#  'lots': {'losts': 0.25, 'lotes': 0.25, 'lot': 0.25, 'lost': 0.25},
#  'propagates': {'propogates': 1.0},
#  'score': {'skore': 0.5, 'scor': 0.5},
#  'side': {'sied': 0.3333333333333333,
#   'se': 0.3333333333333333,
#   'sid': 0.3333333333333333},
#  'preserve': {'preseve': 1.0},
#  'claws': {'clors': 1.0},
#  'never': {'neve*2': 0.10526315789473684,
#   'newer': 0.05263157894736842,
#   'mever': 0.05263157894736842,
#   'nere': 0.05263157894736842,
#   'nof': 0.05263157894736842,
#   'knver': 0.05263157894736842,
#   'neaver': 0.05263157894736842,
#   'nether*2': 0.10526315789473684,
#   'nef': 0.05263157894736842,
#   'neiver': 0.05263157894736842,
#   'nerth': 0.05263157894736842,
#   'naver': 0.05263157894736842,
#   'nven': 0.05263157894736842,
#   'nese': 0.05263157894736842,
#   'ner': 0.05263157894736842,
#   'neven': 0.05263157894736842,
#   'nver': 0.05263157894736842},
#  'extend': {'exstend': 0.5, 'extand': 0.5},
#  'nature': {'nacher': 0.25, 'nuture': 0.25, 'natior': 0.25, 'm': 0.25},
#  'rolled': {'rolld': 0.5, 'rold': 0.5},
#  'invigorated': {'envigorated': 1.0},
#  'souvenir': {'souvenier': 0.3333333333333333,
#   'suvenere': 0.3333333333333333,
#   'souviner': 0.3333333333333333},
#  'extent': {'exstent': 1.0},
#  'wheelbarrow': {'wheel_barrow': 1.0},
#  'debt': {'dept': 0.5, 'deat': 0.5},
#  'tyranny': {'tyrrany*2': 0.6666666666666666, 'tyrany': 0.3333333333333333},
#  'patented': {'pattented': 1.0},
#  'accident': {'and': 0.013513513513513514,
#   'aserdent': 0.013513513513513514,
#   'exded': 0.013513513513513514,
#   'asden': 0.013513513513513514,
#   'sedent': 0.013513513513513514,
#   'acadent': 0.013513513513513514,
#   'ataren': 0.013513513513513514,
#   'axcident': 0.013513513513513514,
#   'askendent': 0.013513513513513514,
#   'castan': 0.013513513513513514,
#   'asdent': 0.013513513513513514,
#   'anitharent': 0.013513513513513514,
#   'esadend': 0.013513513513513514,
#   'a_canet': 0.013513513513513514,
#   'acedcedt': 0.013513513513513514,
#   'asde': 0.013513513513513514,
#   'anteght': 0.013513513513513514,
#   'aciddent': 0.013513513513513514,
#   'accicent': 0.013513513513513514,
#   'andandn': 0.013513513513513514,
#   'acciendent': 0.013513513513513514,
#   'aciedent': 0.013513513513513514,
#   'askedent': 0.013513513513513514,
#   'agisted': 0.013513513513513514,
#   'axedet': 0.013513513513513514,
#   'ascended': 0.013513513513513514,
#   'accierdent': 0.013513513513513514,
#   'asident': 0.013513513513513514,
#   'acsident': 0.013513513513513514,
#   'asedend': 0.013513513513513514,
#   'exedelt': 0.013513513513513514,
#   'harcent': 0.013513513513513514,
#   'accsident': 0.013513513513513514,
#   'andexns': 0.013513513513513514,
#   'acsdent': 0.013513513513513514,
#   'accend': 0.013513513513513514,
#   'axseadent': 0.013513513513513514,
#   'andet': 0.013513513513513514,
#   'accxident': 0.013513513513513514,
#   'aciadent': 0.013513513513513514,
#   'exiedent': 0.013513513513513514,
#   'axs': 0.013513513513513514,
#   'axerdent': 0.013513513513513514,
#   'advainet': 0.013513513513513514,
#   'exedent': 0.013513513513513514,
#   'andires': 0.013513513513513514,
#   'acsedent': 0.013513513513513514,
#   'andient': 0.013513513513513514,
#   'asadun': 0.013513513513513514,
#   'akcdent': 0.013513513513513514,
#   'acedent': 0.013513513513513514,
#   'axed': 0.013513513513513514,
#   'andint': 0.013513513513513514,
#   'ancident': 0.013513513513513514,
#   'aken': 0.013513513513513514,
#   'ased': 0.013513513513513514,
#   'asabed': 0.013513513513513514,
#   'acident': 0.013513513513513514,
#   'afanat': 0.013513513513513514,
#   'xedet': 0.013513513513513514,
#   'axedent': 0.013513513513513514,
#   'acist': 0.013513513513513514,
#   'acdent': 0.013513513513513514,
#   'acs': 0.013513513513513514,
#   'axidint': 0.013513513513513514,
#   'acats': 0.013513513513513514,
#   'asterdet': 0.013513513513513514,
#   'accdient': 0.013513513513513514,
#   'axedents': 0.013513513513513514,
#   'acddent': 0.013513513513513514,
#   'axident': 0.013513513513513514,
#   'addinent': 0.013513513513513514,
#   'acdend': 0.013513513513513514,
#   'accedent': 0.013513513513513514},
#  'chirped': {'cherped': 1.0},
#  'country': {'ocuntry': 0.14285714285714285,
#   'carty': 0.14285714285714285,
#   'cout': 0.14285714285714285,
#   'contry': 0.14285714285714285,
#   'county': 0.14285714285714285,
#   'coontry': 0.14285714285714285,
#   'countrie': 0.14285714285714285},
#  'teddy_boy': {'teddoy': 0.2, 'tedeboy*4': 0.8},
#  'incense': {'insense': 1.0},
#  'levitating': {'levetating': 1.0},
#  'planned': {'planed*2': 1.0},
#  'asked': {'ask*5': 0.625, 'askt': 0.125, 'arsed*2': 0.25},
#  'unsymmetrical': {'unsyme': 1.0},
#  'vain': {'vane': 1.0},
#  'humming': {'huming': 1.0},
#  'cardboard': {'cardbord': 1.0},
#  'source': {'sorce': 0.25, 'aource': 0.25, 'sauce': 0.25, 'sourse': 0.25},
#  'union': {'unioun': 1.0},
#  'criticised': {'critisized': 1.0},
#  'much': {'must': 0.125, 'mush*5': 0.625, 'march': 0.125, 'mach': 0.125},
#  'stadium': {'staydium': 1.0},
#  'privilege': {'priviledge*3': 0.06,
#   'privlage': 0.02,
#   'privelege*2': 0.04,
#   'privelige*2': 0.04,
#   'privaledge': 0.02,
#   'pervieledges': 0.02,
#   'prilavage': 0.02,
#   'privoledge': 0.02,
#   'prevelige': 0.02,
#   'privilages': 0.02,
#   'privielage': 0.02,
#   'priviliage': 0.02,
#   'previlege': 0.02,
#   'prlige': 0.02,
#   'privaledged': 0.02,
#   'prilavge': 0.02,
#   'providge': 0.02,
#   'privelage': 0.02,
#   'privelidge': 0.02,
#   'privileged': 0.02,
#   'priviladge': 0.02,
#   'previllage': 0.02,
#   'privieloge': 0.02,
#   'priveelege': 0.02,
#   'privilage*2': 0.04,
#   'preminage': 0.02,
#   'previlage': 0.02,
#   'previlidge': 0.02,
#   'privalogy': 0.02,
#   'privalidge': 0.02,
#   'priviage': 0.02,
#   'privilidged': 0.02,
#   'purlgy': 0.02,
#   'privledge': 0.02,
#   'prividleged': 0.02,
#   'privileelge': 0.02,
#   'privalage': 0.02,
#   'prilviage': 0.02,
#   'prevelage': 0.02,
#   'privialage': 0.02,
#   'privilidge': 0.02,
#   'privilige': 0.02,
#   'prilvege': 0.02,
#   'priveleage': 0.02,
#   'privi': 0.02},
#  'fry': {'fri': 0.5, 'frie': 0.5},
#  'incompetent': {'incompetant': 1.0},
#  'life': {'lif': 0.25, 'lief': 0.25, 'live': 0.25, 'lefe': 0.25},
#  'spit': {'spite': 1.0},
#  'eastern': {'eastren': 1.0},
#  'wish': {'wich': 0.3333333333333333,
#   'wis': 0.3333333333333333,
#   'whish': 0.3333333333333333},
#  'lift': {'left': 1.0},
#  'toboggan': {'talogon': 0.030303030303030304,
#   'tabogan': 0.030303030303030304,
#   'tabogen': 0.030303030303030304,
#   'tobbogan': 0.030303030303030304,
#   'tabogoon': 0.030303030303030304,
#   'tobagon': 0.030303030303030304,
#   'tobagan': 0.030303030303030304,
#   'tobogon': 0.030303030303030304,
#   'tobugon': 0.030303030303030304,
#   'tobogan': 0.030303030303030304,
#   'tobon': 0.030303030303030304,
#   'taboggan': 0.030303030303030304,
#   'tobogar': 0.030303030303030304,
#   'tobbogen': 0.030303030303030304,
#   'tobogurn': 0.030303030303030304,
#   'tobogn': 0.030303030303030304,
#   'taboog': 0.030303030303030304,
#   'tobaggan': 0.030303030303030304,
#   'tobboan': 0.030303030303030304,
#   'tabbogan': 0.030303030303030304,
#   'torbogen': 0.030303030303030304,
#   'conboggon': 0.030303030303030304,
#   'tobag': 0.030303030303030304,
#   'toboggen': 0.030303030303030304,
# ...
#  'bandage': {'bandge': 1.0},
#  'vacuum': {'vaccume': 0.5, 'vaccum': 0.5},
#  'world': {'wald': 0.14285714285714285,
#   'worde': 0.14285714285714285,
#   'word': 0.14285714285714285,
#   'would': 0.14285714285714285,
#   'wholed': 0.14285714285714285,
#   'wold': 0.14285714285714285,
#   'wourld': 0.14285714285714285},
#  'postal': {'postel': 1.0},
#  'decomposes': {'decomposits': 1.0},
#  'vague': {'vaig': 0.5, 'vage': 0.5},
#  'dare': {'dear': 0.5, 'dair': 0.5},
#  'satisfaction': {'shasan': 0.010309278350515464,
#   'satichfatshen': 0.010309278350515464,
#   'satisfacshoin': 0.010309278350515464,
#   'satisfacshion': 0.010309278350515464,
#   'wanat': 0.010309278350515464,
#   'sabfas': 0.010309278350515464,
#   'istis': 0.010309278350515464,
#   'satisfacshin': 0.010309278350515464,
#   'satisfashoin': 0.010309278350515464,
#   'satisfacsion': 0.010309278350515464,
#   'satfacso': 0.010309278350515464,
#   'sachfachn': 0.010309278350515464,
#   'stisfacho': 0.010309278350515464,
#   'satlistash': 0.010309278350515464,
#   'satisfacion': 0.010309278350515464,
#   'satesfaction': 0.010309278350515464,
#   'satisfation': 0.010309278350515464,
#   'satiusfacson': 0.010309278350515464,
#   'satifacian': 0.010309278350515464,
#   'satefasion': 0.010309278350515464,
#   'satisfactoin': 0.010309278350515464,
#   'satifoin': 0.010309278350515464,
#   'satishfacen': 0.010309278350515464,
#   'satisfaften': 0.010309278350515464,
#   'satfaction': 0.010309278350515464,
#   'sackaach': 0.010309278350515464,
#   'satfakess': 0.010309278350515464,
#   'satifactoin': 0.010309278350515464,
#   'saciffaction': 0.010309278350515464,
#   'satfacan': 0.010309278350515464,
#   'satisfacttion': 0.010309278350515464,
#   'satamachen': 0.010309278350515464,
#   'satishfation': 0.010309278350515464,
#   'silhen_fant': 0.010309278350515464,
#   'sacfatchen': 0.010309278350515464,
#   'satesfach_chere': 0.010309278350515464,
#   'satisfn': 0.010309278350515464,
#   'satirsh': 0.010309278350515464,
#   'siterfatur': 0.010309278350515464,
#   'satisfatch': 0.010309278350515464,
#   'eat_as_of_ede': 0.010309278350515464,
#   'satishfaction': 0.010309278350515464,
#   'satisfakshion': 0.010309278350515464,
#   'fian': 0.010309278350515464,
#   'satisfacshon': 0.010309278350515464,
#   'satifation': 0.010309278350515464,
#   'setisfate': 0.010309278350515464,
#   'satifachen': 0.010309278350515464,
#   'satishfaktion': 0.010309278350515464,
#   'satifishan': 0.010309278350515464,
#   'satitfaction': 0.010309278350515464,
#   'sat_oford': 0.010309278350515464,
#   'sartfasn': 0.010309278350515464,
#   'sats_fan': 0.010309278350515464,
#   'satisvetion': 0.010309278350515464,
#   'satisfacshun': 0.010309278350515464,
#   'satfasher': 0.010309278350515464,
#   'sicifaris': 0.010309278350515464,
#   'setitfared': 0.010309278350515464,
#   'sitisfaction': 0.010309278350515464,
#   'satisfuckshon': 0.010309278350515464,
#   'satishan': 0.010309278350515464,
#   'sat_fainand': 0.010309278350515464,
#   'sachen': 0.010309278350515464,
#   'sachfaen': 0.010309278350515464,
#   'statsiefacsed': 0.010309278350515464,
#   'argring_atoing': 0.010309278350515464,
#   'satigan': 0.010309278350515464,
#   'satichfachcen': 0.010309278350515464,
#   'satisfachan': 0.010309278350515464,
#   'satiffashon': 0.010309278350515464,
#   'sacisfacsh': 0.010309278350515464,
#   'satisfakson': 0.010309278350515464,
#   'satisfackshen': 0.010309278350515464,
#   'sackitvansh': 0.010309278350515464,
#   'satifaction': 0.010309278350515464,
#   'satifachon': 0.010309278350515464,
#   'satisfachen': 0.010309278350515464,
#   'soam': 0.010309278350515464,
#   'sackifsacshern': 0.010309278350515464,
#   'sattfashed': 0.010309278350515464,
#   'satsha': 0.010309278350515464,
#   'satifason': 0.010309278350515464,
#   'satispachoin': 0.010309278350515464,
#   'saticfacon': 0.010309278350515464,
#   'satisfakshon': 0.010309278350515464,
#   'satisfacin': 0.010309278350515464,
#   'call_fall': 0.010309278350515464,
#   'satisfcshion': 0.010309278350515464,
#   'satifacion': 0.010309278350515464,
#   'satistloin': 0.010309278350515464,
#   'satigaction': 0.010309278350515464,
#   'satisfackshon': 0.010309278350515464,
#   'satesfacshen': 0.010309278350515464,
#   'satisfachshon': 0.010309278350515464,
#   'satfatre': 0.010309278350515464,
#   'satisfain': 0.010309278350515464},
#  'unrepentant': {'unrepentent': 1.0},
#  'nutrients': {'nutritents': 1.0},
#  'souvenirs': {'souveniers': 1.0},
#  'discarded': {'discare': 1.0},
#  'stationary': {'stationery': 1.0},
#  'clap': {'klap': 0.5, 'clape': 0.5},
#  'auditorium': {'autorm': 0.015873015873015872,
#   'autoruim': 0.015873015873015872,
#   'auditormunen': 0.015873015873015872,
#   'audiatorum': 0.015873015873015872,
#   'auditouim': 0.015873015873015872,
#   'allturman': 0.015873015873015872,
#   'audatoreum': 0.015873015873015872,
#   'oratoroum': 0.015873015873015872,
#   'autitorium': 0.015873015873015872,
#   'auditorm': 0.015873015873015872,
#   'additorium': 0.015873015873015872,
#   'auditorim': 0.015873015873015872,
#   'autormen': 0.015873015873015872,
#   'allortomdd': 0.015873015873015872,
#   'audaterame': 0.015873015873015872,
#   'adutorium': 0.015873015873015872,
#   'auditarium': 0.015873015873015872,
#   'auditory': 0.015873015873015872,
#   'attorium': 0.015873015873015872,
#   'audetorium': 0.015873015873015872,
#   'audotorium': 0.015873015873015872,
#   'auditourin': 0.015873015873015872,
#   'auditorial': 0.015873015873015872,
#   'auditoriam': 0.015873015873015872,
#   'autorum': 0.015873015873015872,
#   'auditoruium': 0.015873015873015872,
#   'autotorium': 0.015873015873015872,
#   'autatorum': 0.015873015873015872,
#   'autatorom': 0.015873015873015872,
#   'adetoreum': 0.015873015873015872,
#   'aduoteriam': 0.015873015873015872,
#   'auditorinum': 0.015873015873015872,
#   'audatorum': 0.015873015873015872,
#   'auttortism': 0.015873015873015872,
#   'auditiorm': 0.015873015873015872,
#   'audortum': 0.015873015873015872,
#   'ouditorium': 0.015873015873015872,
#   'auditorum': 0.015873015873015872,
#   'auditoium': 0.015873015873015872,
#   'auditoryum': 0.015873015873015872,
#   'auditoriom': 0.015873015873015872,
#   'auditorimn': 0.015873015873015872,
#   'adatorum': 0.015873015873015872,
#   'auditorym': 0.015873015873015872,
#   'arudtiorze': 0.015873015873015872,
#   'auditormeon': 0.015873015873015872,
#   'auditorumen': 0.015873015873015872,
#   'authorium': 0.015873015873015872,
#   'auditoreum': 0.015873015873015872,
#   'ottatorium': 0.015873015873015872,
#   'audiotorium': 0.015873015873015872,
#   'autitorum': 0.015873015873015872,
#   'audiortium': 0.015873015873015872,
#   'attoram': 0.015873015873015872,
#   'audetorn': 0.015873015873015872,
#   'auditor': 0.015873015873015872,
#   'audatorium': 0.015873015873015872,
#   'audortorium': 0.015873015873015872,
#   'auditoriumn': 0.015873015873015872,
#   'aduitorum': 0.015873015873015872,
#   'auditoriun': 0.015873015873015872,
#   'aditorum': 0.015873015873015872,
#   'aditorium': 0.015873015873015872},
#  'satisfactory': {'satsfactory': 0.3333333333333333,
#   'satifactory': 0.3333333333333333,
#   'satisfactary': 0.3333333333333333},
#  'superintendent': {'superintendant': 0.5, 'supertendent': 0.5},
#  'learning': {'learnning': 0.25,
#   'learing': 0.25,
#   'lerning': 0.25,
#   'learining': 0.25},
#  'supplementary': {'suplementary': 1.0},
#  'divine': {'devin': 0.1,
#   'devying': 0.1,
#   'divide': 0.1,
#   'deavine': 0.1,
#   'devide': 0.1,
#   'devine': 0.1,
#   'devined': 0.1,
#   'delvine': 0.1,
#   'divene': 0.1,
#   'define': 0.1},
#  'thinks': {'thikns': 1.0},
#  "there'll": {'therell': 1.0},
#  'memories': {'memoirs': 0.023809523809523808,
#   'mearise': 0.023809523809523808,
#   'memeroies': 0.023809523809523808,
#   'momories': 0.023809523809523808,
#   'memerories': 0.023809523809523808,
#   'meherey': 0.023809523809523808,
#   'merrerys': 0.023809523809523808,
#   'memoaries': 0.023809523809523808,
#   'memoraries': 0.023809523809523808,
#   'merries': 0.023809523809523808,
#   'mermarys': 0.023809523809523808,
#   'mermories': 0.023809523809523808,
#   "memory's": 0.023809523809523808,
#   'remison': 0.023809523809523808,
#   'memordies': 0.023809523809523808,
#   'memorries': 0.023809523809523808,
#   'mearsise': 0.023809523809523808,
#   'memey': 0.023809523809523808,
#   'memory': 0.023809523809523808,
#   'memoiries': 0.023809523809523808,
#   'memuries': 0.023809523809523808,
#   'memoreys': 0.023809523809523808,
#   'merrors': 0.023809523809523808,
#   'memmories': 0.023809523809523808,
#   'moniiy': 0.023809523809523808,
#   'monorious': 0.023809523809523808,
#   'merories': 0.023809523809523808,
#   'memeris': 0.023809523809523808,
#   'merores': 0.023809523809523808,
#   'moremery': 0.023809523809523808,
#   'memoreres': 0.023809523809523808,
#   'marysis': 0.023809523809523808,
#   'memoryes': 0.023809523809523808,
#   'memorarys': 0.023809523809523808,
#   'memouries': 0.023809523809523808,
#   "memorie's": 0.023809523809523808,
#   'memorys': 0.023809523809523808,
#   'memeries': 0.023809523809523808,
#   'mermiores': 0.023809523809523808,
#   'memmorys': 0.023809523809523808,
#   'memerys': 0.023809523809523808,
#   'mamrioes': 0.023809523809523808},
#  'noon': {'non': 1.0},
#  'endocrine': {'endochrine': 1.0},
#  'refer': {'refere': 1.0},
#  'unsuccessfully': {'unsucesfuly': 0.5, 'unsucessfully': 0.5},
#  'accessing': {'accesing': 1.0},
#  'scientific': {'scientic': 0.3333333333333333,
#   'scienfic': 0.3333333333333333,
#   'st': 0.3333333333333333},
#  'power': {'pwoer': 0.5, 'pour': 0.5},
#  'intimate': {'intermit': 1.0},
#  'in_spite': {'inspite': 1.0},
#  'playing-field': {'playfud': 0.3333333333333333,
#   'playing_field': 0.3333333333333333,
#   'playfeild': 0.3333333333333333},
#  'stone': {'ston': 1.0},
#  'package': {'packege': 0.5, 'pakage': 0.5},
#  'disabilities': {'dissabiliteys': 1.0},
#  'meal': {'mel': 0.5, 'mell': 0.5},
#  'neighbor': {'neighbour': 0.5, 'neigbour': 0.5},
#  'act': {'at': 0.5, 'akt': 0.5},
#  'luck': {'lock': 1.0},
#  'rabbinical': {'rabinnical': 1.0},
#  'burning': {'buring': 1.0},
#  'legged': {'leged': 1.0},
#  'lively': {'livly': 0.5, 'livley': 0.5},
#  'parties': {'partys': 0.5, "party's": 0.5},
#  'accumulated': {'acumulated': 1.0},
#  'technically': {'technecally': 0.5, 'techniquely': 0.5},
#  'burglar': {'burgler': 0.5, 'buglar': 0.5},
#  'her': {'hir': 0.06666666666666667,
#   'there': 0.06666666666666667,
#   'them': 0.06666666666666667,
#   'here*16': 0.4,
#   'She': 0.06666666666666667,
#   'har': 0.06666666666666667,
#   'he*4': 0.26666666666666666},
#  'series': {'serious': 1.0},
#  'water-rat': {'waterrat': 1.0},
#  'bubble': {'buble': 1.0},
#  'yearned': {'yerned': 1.0},
#  'complete': {'compleat': 1.0},
#  'beginners': {'begginers': 1.0},
#  'elimination': {'eleimination': 0.5, 'elimiation': 0.5},
#  'impedance': {'impedence*2': 1.0},
#  'mice': {'mise': 1.0},
#  'with': {'whin': 0.02631578947368421,
#   'wif': 0.02631578947368421,
#   'wefe': 0.02631578947368421,
#   'wis*2': 0.05263157894736842,
#   'in': 0.02631578947368421,
#   'whit': 0.02631578947368421,
#   'iwth': 0.02631578947368421,
#   'wihth': 0.02631578947368421,
#   'wiy': 0.02631578947368421,
#   'will': 0.02631578947368421,
#   'what': 0.02631578947368421,
#   'wef': 0.02631578947368421,
#   'wien': 0.02631578947368421,
#   'when': 0.02631578947368421,
#   'wthe': 0.02631578947368421,
#   'whith': 0.02631578947368421,
#   'wethe': 0.02631578947368421,
#   'wivr': 0.02631578947368421,
#   'we': 0.02631578947368421,
#   'wihe': 0.02631578947368421,
#   'wh': 0.02631578947368421,
#   'wite': 0.02631578947368421,
#   'wiht*3': 0.07894736842105263,
#   'wive': 0.02631578947368421,
#   'wirth': 0.02631578947368421,
#   'went': 0.02631578947368421,
#   'wtih': 0.02631578947368421,
#   'withe': 0.02631578947368421,
#   'wint': 0.02631578947368421,
#   'weth': 0.02631578947368421,
#   'wit': 0.02631578947368421,
#   'yethe': 0.02631578947368421,
#   'witht': 0.02631578947368421,
#   'the': 0.02631578947368421,
#   'wheth': 0.02631578947368421},
#  'buying': {'buyin': 0.5, 'bying': 0.5},
#  'handsome': {'hansem': 0.3333333333333333,
#   'hansum': 0.3333333333333333,
#   'hansome': 0.3333333333333333},
#  "they're": {'their': 0.2, 'the': 0.2, 'there*2': 0.4, 'thier': 0.2},
#  'rush': {'ruch': 1.0},
#  'monopoly': {'monapaloy': 1.0},
#  'dirty': {'dertses': 0.25, 'diry': 0.25, 'driy': 0.25, 'durty': 0.25},
#  'dispensing': {'dispencing': 1.0},
#  'agree': {'agre*2': 1.0},
#  'detailed': {'detailled*2': 1.0},
#  'gone': {'gon*2': 0.18181818181818182,
#   'crome': 0.09090909090909091,
#   'gome': 0.09090909090909091,
#   'goon': 0.09090909090909091,
#   'gonne': 0.09090909090909091,
#   'gornd': 0.09090909090909091,
#   'go*3': 0.2727272727272727,
#   'gor': 0.09090909090909091},
#  'gratuitous': {'gratuitious': 1.0},
#  'exhausted': {'exausted': 0.3333333333333333,
#   'exhasted': 0.3333333333333333,
#   'exa': 0.3333333333333333},
#  'certain': {'sorton': 0.1111111111111111,
#   'certian': 0.1111111111111111,
#   'surntered': 0.1111111111111111,
#   'sirtain': 0.1111111111111111,
#   'ceratin': 0.1111111111111111,
#   'curtain': 0.1111111111111111,
#   'sertain': 0.1111111111111111,
#   'cirtain': 0.1111111111111111,
#   'serton': 0.1111111111111111},
#  'accents': {'achsends': 1.0},
#  'Cinderella': {'Cinderrella': 1.0},
#  'am': {'ham': 0.5, 'an': 0.5},
#  'an': {'a*2': 0.2857142857142857,
#   'and*2': 0.2857142857142857,
#   'un': 0.14285714285714285,
#   'am': 0.14285714285714285,
#   'on': 0.14285714285714285},
#  'as': {'ass': 0.06666666666666667,
#   'a': 0.06666666666666667,
#   'his': 0.06666666666666667,
#   'asw': 0.06666666666666667,
#   'have': 0.06666666666666667,
#   'was': 0.06666666666666667,
#   'hase': 0.06666666666666667,
#   'is': 0.06666666666666667,
#   'tes': 0.06666666666666667,
#   'at': 0.06666666666666667,
#   'aas': 0.06666666666666667,
#   'has*2': 0.13333333333333333,
#   'saw': 0.06666666666666667,
#   'als': 0.06666666666666667},
#  'at': {'a*3': 0.3,
#   'ast': 0.1,
#   'al': 0.1,
#   'an': 0.1,
#   'as': 0.1,
#   'are*2': 0.2,
#   'att': 0.1},
#  'hobbies': {'hobbys': 1.0},
#  'creak': {'creek': 1.0},
#  'cream': {'crem': 1.0},
#  'ideally': {'idealy': 1.0},
#  'graduate': {'graguate': 1.0},
#  'tight': {'tite': 1.0},
#  'Watson': {'watston': 1.0},
#  'unparalleled': {'umparralled': 0.023809523809523808,
#   'unparralel': 0.023809523809523808,
#   'unparalleld': 0.023809523809523808,
#   'unparallelled': 0.023809523809523808,
#   'unparlleled': 0.023809523809523808,
#   'parrealled': 0.023809523809523808,
#   'apparrelled': 0.023809523809523808,
#   'unparralleled': 0.023809523809523808,
#   'unparreled': 0.023809523809523808,
#   'unparielled': 0.023809523809523808,
#   'empalerleld': 0.023809523809523808,
#   'uparrelled': 0.023809523809523808,
#   'unparalled': 0.023809523809523808,
#   'unplaled': 0.023809523809523808,
#   'unparlled': 0.023809523809523808,
#   'unparallel': 0.023809523809523808,
#   'anparelle': 0.023809523809523808,
#   'unparelled': 0.023809523809523808,
#   'unpall': 0.023809523809523808,
#   'unparrelede': 0.023809523809523808,
#   'un-parrallel': 0.023809523809523808,
#   'unblale': 0.023809523809523808,
#   'unparale': 0.023809523809523808,
#   'unperalld': 0.023809523809523808,
#   'unparalel': 0.023809523809523808,
#   'unparrowllede': 0.023809523809523808,
#   'unparolled': 0.023809523809523808,
#   'unparalelled': 0.023809523809523808,
#   'unparaled': 0.023809523809523808,
#   'unpovaly': 0.023809523809523808,
#   'unparralled': 0.023809523809523808,
#   'unparraled': 0.023809523809523808,
#   'unparrallel': 0.023809523809523808,
#   'unparrled': 0.023809523809523808,
#   'unpareled': 0.023809523809523808,
#   'unapparralled': 0.023809523809523808,
#   'unparraleled': 0.023809523809523808,
#   'unparelelled': 0.023809523809523808,
#   'unparrelled': 0.023809523809523808,
#   'unparelleled': 0.023809523809523808,
#   'andpiotou': 0.023809523809523808,
#   'unproloud': 0.023809523809523808},
#  'puppy': {'pupy': 1.0},
#  'contemporaries': {'contamporaries': 1.0},
#  'congress': {'converce': 0.1111111111111111,
#   'curgress': 0.1111111111111111,
#   'Congress': 0.1111111111111111,
#   'converse': 0.1111111111111111,
#   'Cnongress': 0.1111111111111111,
#   'cangress': 0.1111111111111111,
#   'congres': 0.1111111111111111,
#   'Comgress': 0.1111111111111111,
#   'congeres': 0.1111111111111111},
#  'spermatozoa': {'spermatozoan': 1.0},
#  'tiger': {'tigar': 1.0},
#  'partitioned': {'petitioned': 1.0},
#  'mask': {'mast': 0.3333333333333333,
#   'masked': 0.3333333333333333,
#   'marsk': 0.3333333333333333},
#  'having': {'haveing*2': 0.4, 'hvaing': 0.2, 'have-ing': 0.2, 'hower': 0.2},
#  ...}

# %% [markdown]
# -----
#
# #### 第三步：选用nltk语料库movie_reviews，构建bigram语言模型；统计p(正确的单词)的概率分布。
# > 可以尝试使用不同的预料库来构建bigram模型；movie_reviews中的语料库较小，test_data中很多词都在该语料库中没有包含，模型性能较差。
# > 建议方法：\
# 1.nltk中多个语料库共同构建。\
# 2.自定义更相关的语料库(观察test_data中主要是什么领域的文本，找相关领域的语料集)。

# %%
from nltk.corpus import movie_reviews

# 读取语料库
categories = movie_reviews.categories()
corpus = movie_reviews.sents(categories=categories)

# bigram Condition on the previous word
# 根据前一个单词预测后一个单词

words = {}
bigrams = {}
start = '(START)'
end = '(END)'
word_cnt = 0.0
bi_cnt = 0.0

for sentence in corpus:
    sentence : list # 遍历语料库的句子
    sentence.insert(0, start) # 加上开始标志
    sentence.append(end)
    
    for i in range(len(sentence)):
        word = sentence[i] 
        word_cnt += 1
        # 计算单词和双词的出现频率
        # 这里没有去掉符号，后续可以像前面的作业那样去掉标点，小写化再进行后续操作
        if word in words:
            words[word] += 1 
        else:
            words[word] = 1
    
    for i in range(len(sentence) - 1):  
        bi_cnt += 1  
        bigram = sentence[i : i + 2]
        bigram = bigram[0] + " " + bigram[1]
        if bigram in bigrams:
            bigrams[bigram] += 1
        else:
            bigrams[bigram] = 1
    
for word in words:
    words[word] /= word_cnt
    # print(words[word])
for bigram in bigrams:
    bigrams[bigram] /= bi_cnt

# %%
words
# Out:
# {'(START)': 0.0380660500625315,
#  'plot': 0.0008825574449816139,
#  ':': 0.001774447949526814,
#  'two': 0.001114717301625819,
#  'teen': 8.808074963134415e-05,
#  'couples': 1.5749538013551602e-05,
#  'go': 0.0006492309558919605,
#  'to': 0.01862937020514065,
#  'a': 0.02222784798312583,
#  'church': 4.0248819367965205e-05,
#  'party': 0.00010674686875851642,
#  ',': 0.045333586881451476,
#  'drink': 1.866611912717227e-05,
#  'and': 0.02075205793963377,
#  'then': 0.000830642301159166,
#  'drive': 6.124820338603401e-05,
#  '.': 0.03842653948817502,
#  '(END)': 0.0380660500625315,
#  'they': 0.0028145007746439438,
#  'get': 0.0011368833180893361,
#  'into': 0.0015300384522054019,
#  'an': 0.0033505683833274223,
#  'accident': 6.066488716330988e-05,
#  'one': 0.0034135665353816286,
#  'of': 0.019904499468015605,
#  'the': 0.04464060720885521,
#  'guys': 0.00015632874769006775,
#  'dies': 6.066488716330988e-05,
#  'but': 0.005036352267000168,
#  'his': 0.005592252627256268,
#  'girlfriend': 0.00012716293655386108,
#  'continues': 5.1331827599723744e-05,
#  'see': 0.0010202200735445093,
#  'him': 0.0015358716144326433,
#  'in': 0.01272912661228604,
#  'her': 0.0026377559591585316,
#  'life': 0.0009251395292404756,
#  'has': 0.002752669255035186,
#  'nightmares': 1.516622179082747e-05,
#  'what': 0.0019377764918895712,
#  "'": 0.01784072667201762,
#  's': 0.010798933231291882,
#  'deal': 0.00012774625277658523,
#  '?': 0.002199685475892707,
#  'watch': 0.0003517396823026525,
#  'movie': 0.003366317921340974,
#  '"': 0.010273365314617438,
#  'sorta': 5.833162227241334e-06,
#  'find': 0.0004561532861702723,
#  'out': 0.002121521102047673,
#  'critique': 3.558228958617214e-05,
#  'mind': 0.00026307561644858417,
#  '-': 0.009096816493382861,
#  'fuck': 9.916375786310269e-06,
#  'for': 0.005810412894555093,
#  'generation': 5.599835738151681e-05,
#  'that': 0.0092887275306591,
#  'touches': 3.208239224982734e-05,
#  'on': 0.0043077903048177255,
#  'very': 0.0010867181229350605,
#  'cool': 0.00012132977432661975,
#  'idea': 0.0002251600619715155,
#  'presents': 4.549866537248241e-05,
#  'it': 0.009395474399417618,
#  'bad': 0.0008137261307001662,
#  'package': 1.7499486681724004e-05,
#  'which': 0.0018438625800309858,
#  'is': 0.01469665223153454,
#  'makes': 0.0005786496929423403,
#  'this': 0.00558700278125175,
#  'review': 0.00017207828570361936,
#  'even': 0.0014962061112874022,
#  'harder': 1.9249435349896403e-05,
#  'write': 6.941463050417187e-05,
#  'since': 0.0004479868590521345,
#  'i': 0.005185097903794822,
#  'generally': 6.008157094058574e-05,
#  'applaud': 5.833162227241334e-06,
#  'films': 0.000895973718104269,
#  'attempt': 0.0001534121665764471,
#  'break': 0.00010208033897672334,
#  'mold': 8.166427118137868e-06,
#  'mess': 9.274727941313721e-05,
#  'with': 0.006295148675638848,
#  'your': 0.0005004853190973065,
#  'head': 0.00022574337819423963,
#  'such': 0.0007110624755007186,
#  '(': 0.006803800421854292,
#  'lost': 0.00023857633509417057,
#  'highway': 1.6332854236275736e-05,
#  '&': 0.0001709116532581711,
#  'memento': 5.833162227241334e-06,
#  ')': 0.006872048419913016,
#  'there': 0.002199102159669983,
#  'are': 0.004053464431710003,
#  'good': 0.0014063754129878857,
#  'ways': 0.00011024676609486122,
#  'making': 0.00035115636607992834,
#  'all': 0.0025508418419726356,
#  'types': 2.7999178690758405e-05,
#  'these': 0.0007635609355458907,
#  'folks': 4.316540048158587e-05,
#  'just': 0.0016945336270136075,
#  'didn': 0.00033774009295727323,
#  't': 0.003739056987661695,
#  'snag': 1.1666324454482668e-06,
#  'correctly': 9.916375786310269e-06,
#  'seem': 0.0003348235118436526,
#  'have': 0.002858832807570978,
#  'taken': 0.00013124615011293002,
#  'pretty': 0.00030799096559834245,
#  'neat': 1.866611912717227e-05,
#  'concept': 6.64980493905512e-05,
#  'executed': 2.6832546245310137e-05,
#  'terribly': 3.383234091799974e-05,
#  'so': 0.0021483536482929835,
#  'problems': 0.0001709116532581711,
#  'well': 0.0011118007205121983,
#  'its': 0.0013241278255837828,
#  'main': 0.00023274317286692923,
#  'problem': 0.00023099322419875684,
#  'simply': 0.0002496593433259291,
#  'too': 0.0009198896832359584,
#  'jumbled': 6.999794672689601e-06,
#  'starts': 0.00018432792638082616,
#  'off': 0.0009222229481268549,
#  'normal': 6.474810072237881e-05,
#  'downshifts': 1.1666324454482668e-06,
#  'fantasy': 5.658167360424094e-05,
#  'world': 0.0006048989229649264,
#  'you': 0.0031009090400014932,
#  'as': 0.00663697198215519,
#  'audience': 0.0005331510275698579,
#  'member': 7.349784406324081e-05,
#  'no': 0.0014419577025740577,
#  'going': 0.0005179848057790305,
#  'dreams': 7.641442517686148e-05,
#  'characters': 0.001084384858044164,
#  'coming': 0.0001604119612491367,
#  'back': 0.0006183151960875814,
#  'from': 0.002915997797397943,
#  'dead': 0.00024382618109868777,
#  'others': 0.00016799507214455042,
#  'who': 0.0033202359397457673,
#  'look': 0.0004870690459746514,
#  'like': 0.002152436861852052,
#  'strange': 0.00010791350120396468,
#  'apparitions': 2.916581113620667e-06,
#  'disappearances': 1.7499486681724003e-06,
#  'looooot': 5.833162227241334e-07,
#  'chase': 9.274727941313721e-05,
#  'scenes': 0.000743144867750546,
#  'tons': 1.2249640677206802e-05,
#  'weird': 5.833162227241334e-05,
#  'things': 0.0004969854217609617,
#  'happen': 0.00012832956899930936,
#  'most': 0.0013451272096018517,
#  'not': 0.0032531545741324923,
#  'explained': 4.083213559068934e-05,
#  'now': 0.0005786496929423403,
#  'personally': 2.5665913799861872e-05,
#  'don': 0.0007548111922050287,
#  'trying': 0.00033015698206185953,
#  'unravel': 5.2498460045172006e-06,
#  'film': 0.005551420491665578,
#  'every': 0.0005524004629197544,
#  'when': 0.0019004442536352268,
#  'does': 0.0009146398372314413,
#  'give': 0.0003272404009482389,
#  'me': 0.0008248091389319247,
#  'same': 0.000507485113769996,
#  'clue': 2.6249230022586003e-05,
#  'over': 0.000843475258059097,
#  'again': 0.00040598809101599685,
#  'kind': 0.00032607376850279056,
#  'fed': 1.691617045899987e-05,
#  'up': 0.0019861917383756744,
#  'after': 0.001027803184439923,
#  'while': 0.0008977236667724413,
#  'biggest': 8.691411718589588e-05,
#  'obviously': 0.0001329960987811024,
#  'got': 0.0002741586246803427,
#  'big': 0.000620648460978478,
#  'secret': 0.00010733018498124055,
#  'hide': 2.3332648908965335e-05,
#  'seems': 0.0006025656580740298,
#  'want': 0.00032665708472551474,
#  'completely': 0.00025665913799861873,
#  'until': 0.0002514092919941015,
#  'final': 0.0002216601646351707,
#  'five': 0.0001656618072536539,
#  'minutes': 0.00037565564743434194,
#  'do': 0.0011170505665167156,
#  'make': 0.000957805237713027,
#  'entertaining': 0.0001831612939353779,
#  'thrilling': 2.6832546245310137e-05,
#  'or': 0.001836279469135572,
#  'engaging': 4.608198159520654e-05,
#  'meantime': 1.1083008231758535e-05,
#  'really': 0.0009088066750041998,
#  'sad': 6.299815205420641e-05,
#  'part': 0.00041648778302503126,
#  'arrow': 1.691617045899987e-05,
#  'both': 0.0005209013868926511,
#  'dig': 1.1083008231758535e-05,
#  'flicks': 4.724861404065481e-05,
#  'we': 0.0016187025180594702,
#  'actually': 0.00048823567842009967,
#  'figured': 1.691617045899987e-05,
#  'by': 0.0036521428704757992,
#  'half': 0.00031207417915741137,
#  'way': 0.000987554365071958,
#  'point': 0.0003995716125660314,
#  'strangeness': 3.4998973363448007e-06,
#  'did': 0.0004450702779385138,
#  'start': 0.00018199466148992964,
#  'little': 0.0008755576503089242,
#  'bit': 0.0003313236145073078,
#  'sense': 0.00032374050361189404,
#  'still': 0.0006107320851921677,
#  'more': 0.0019523593974576745,
#  'guess': 0.00013182946633565415,
#  'bottom': 5.424840871334441e-05,
#  'line': 0.000253742556884998,
#  'movies': 0.000703479364605305,
#  'should': 0.0005086517462154443,
#  'always': 0.0003418233065163422,
#  'sure': 0.0003050743844847218,
#  'before': 0.0005786496929423403,
#  'given': 0.000292824743807515,
#  'password': 2.3332648908965336e-06,
#  'enter': 3.9665503145241075e-05,
#  'understanding': 3.32490246952756e-05,
#  'mean': 0.0001411625258992403,
#  'showing': 8.574748474044761e-05,
#  'melissa': 6.999794672689601e-06,
#  'sagemiller': 4.666529781793067e-06,
#  'running': 0.0001884111399398951,
#  'away': 0.0003820721258843074,
#  'visions': 1.8082802904448135e-05,
#  'about': 0.002055023052657122,
#  '20': 5.716498982696508e-05,
#  'throughout': 0.0001761614992626883,
#  'plain': 4.783193026337894e-05,
#  'lazy': 1.9832751572620537e-05,
#  '!': 0.0009992206895264406,
#  'okay': 7.291452784051668e-05,
#  'people': 0.0008487251040636141,
#  'chasing': 2.5082597577137738e-05,
#  'know': 0.0007098958430552703,
#  'need': 0.00018432792638082616,
#  'how': 0.0008848907098725104,
#  'giving': 0.00012482967166296455,
#  'us': 0.0006258983069829952,
#  'different': 0.00025082597577137737,
#  'offering': 2.216601646351707e-05,
#  'further': 7.816437384503387e-05,
#  'insight': 3.1499076027103203e-05,
#  'down': 0.0005541504115879267,
#  'apparently': 0.00012191309054934388,
#  'studio': 9.508054430403375e-05,
#  'took': 9.566386052675788e-05,
#  'director': 0.0007215621675097531,
#  'chopped': 2.916581113620667e-06,
#  'themselves': 0.00016507849103092976,
#  'shows': 0.0002391596513168947,
#  'might': 0.0003704058014298247,
#  've': 0.00048765236219737554,
#  'been': 0.0011957982565844736,
#  'decent': 9.566386052675788e-05,
#  'here': 0.0006929796725962705,
#  'somewhere': 7.408116028596495e-05,
#  'suits': 2.6249230022586003e-05,
#  'decided': 6.066488716330988e-05,
#  'turning': 4.666529781793067e-05,
#  'music': 0.00027999178690758407,
#  'video': 0.00018782782371717097,
#  'edge': 6.066488716330988e-05,
#  'would': 0.0012302139137251975,
#  'actors': 0.0004118212532432382,
#  'although': 0.00046373639706568607,
#  'wes': 2.916581113620667e-05,
#  'bentley': 5.2498460045172006e-06,
#  'seemed': 0.0001236630392175163,
#  'be': 0.0036013943590987997,
#  'playing': 0.0002111604726261363,
#  'exact': 3.733223825434454e-05,
#  'character': 0.0011782987699027496,
#  'he': 0.0051705149982267185,
#  'american': 0.00032607376850279056,
#  'beauty': 7.874769006775802e-05,
#  'only': 0.001455373975696713,
#  'new': 0.0007536445597595804,
#  'neighborhood': 1.2249640677206802e-05,
#  'my': 0.000813142814477442,
#  'kudos': 1.2249640677206802e-05,
#  'holds': 5.2498460045172006e-05,
#  'own': 0.00047540272152016874,
#  'entire': 0.00023799301887144643,
#  'feeling': 0.00013124615011293002,
#  'unraveling': 1.1666324454482668e-06,
#  'overall': 9.333059563586134e-05,
#  'doesn': 0.0007448948164187184,
#  'stick': 4.0248819367965205e-05,
#  'because': 0.0009823045190674408,
#  'entertain': 3.091575980437907e-05,
#  'confusing': 5.483172493606854e-05,
#  'rarely': 5.949825471786161e-05,
#  'excites': 1.1666324454482668e-06,
#  'feels': 0.00012599630410841281,
#  'redundant': 8.166427118137868e-06,
#  'runtime': 4.666529781793067e-06,
#  'despite': 0.00020532731039889498,
#  'ending': 0.00024674276221230845,
#  'explanation': 4.0248819367965205e-05,
#  'craziness': 2.3332648908965336e-06,
#  'came': 0.00010791350120396468,
#  'oh': 0.00012599630410841281,
#  'horror': 0.0002759085733485151,
#  'slasher': 4.899856270882721e-05,
#  'flick': 0.00011432997965393016,
#  'packaged': 1.7499486681724003e-06,
#  'someone': 0.0002339098053123775,
#  'assuming': 8.749743340862002e-06,
#  'genre': 0.00015632874769006775,
#  'hot': 7.408116028596495e-05,
#  'kids': 0.00019132772105351576,
#  'also': 0.0011473830100983704,
#  'wrapped': 2.2749332686241205e-05,
#  'production': 0.00017499486681724001,
#  'years': 0.0004934855244246169,
#  'ago': 0.00011607992832210255,
#  'sitting': 5.424840871334441e-05,
#  'shelves': 7.583110895413735e-06,
#  'ever': 0.00045265338883392753,
#  'whatever': 7.933100629048215e-05,
#  'skip': 2.6249230022586003e-05,
#  'where': 0.0008703078043044071,
#  'joblo': 1.7499486681724004e-05,
#  'nightmare': 3.499897336344801e-05,
#  'elm': 8.166427118137868e-06,
#  'street': 8.166427118137869e-05,
#  '3': 0.00012949620144475763,
#  '7': 6.708136561327535e-05,
#  '/': 0.0005599835738151681,
#  '10': 0.0002619089840031359,
#  'blair': 5.716498982696508e-05,
#  'witch': 6.299815205420641e-05,
#  '2': 0.0002560758217758946,
#  'crow': 3.208239224982734e-05,
#  '9': 4.3748716704310004e-05,
#  'salvation': 8.166427118137868e-06,
#  '4': 0.00011083008231758535,
#  'stir': 1.5749538013551602e-05,
#  'echoes': 1.8082802904448135e-05,
#  '8': 8.166427118137869e-05,
#  'happy': 0.00012541298788568868,
#  'bastard': 2.6832546245310137e-05,
#  'quick': 8.108095495865454e-05,
#  'damn': 5.1331827599723744e-05,
#  'y2k': 2.3332648908965336e-06,
#  'bug': 4.724861404065481e-05,
#  'starring': 0.00010733018498124055,
#  'jamie': 2.4499281354413604e-05,
#  'lee': 0.0001551621152446195,
#  'curtis': 2.1582700240792936e-05,
#  'another': 0.0006538974856737536,
#  'baldwin': 5.1915143822447875e-05,
#  'brother': 0.00015632874769006775,
#  'william': 0.00012016314188117148,
#  'time': 0.0014063754129878857,
#  'story': 0.0012652128870886453,
#  'regarding': 1.8082802904448135e-05,
#  'crew': 0.00012482967166296455,
#  'tugboat': 1.1666324454482668e-06,
#  'comes': 0.0004275707912567898,
#  'across': 0.0001289128852220335,
#  'deserted': 1.2249640677206802e-05,
#  'russian': 3.9665503145241075e-05,
#  'tech': 1.691617045899987e-05,
#  'ship': 0.00015399548279917123,
#  'kick': 3.033244358165494e-05,
#  'power': 0.00013882926100834374,
#  'within': 0.00013241278255837828,
#  'gore': 6.416478449965468e-05,
#  'bringing': 4.724861404065481e-05,
#  'few': 0.0005623168387060647,
#  'action': 0.0006836466130326844,
#  'sequences': 0.0001709116532581711,
#  'virus': 4.491534914975827e-05,
#  'empty': 3.908218692251694e-05,
#  'flash': 3.616560580889627e-05,
#  'substance': 4.258208425886174e-05,
#  'why': 0.000515651540888134,
#  'was': 0.002881582140257219,
#  'middle': 0.00012949620144475763,
#  'nowhere': 5.716498982696508e-05,
#  'origin': 4.666529781793067e-06,
#  'pink': 1.3999589345379203e-05,
#  'flashy': 2.391596513168947e-05,
#  'thing': 0.00047190282418382395,
#  'hit': 0.00016624512347637803,
#  'mir': 4.083213559068934e-06,
#  'course': 0.00037798891232523847,
#  'donald': 2.216601646351707e-05,
#  'sutherland': 2.2749332686241205e-05,
#  'stumbling': 8.749743340862002e-06,
#  'around': 0.0005267345491198925,
#  'drunkenly': 1.1666324454482668e-06,
#  'hey': 4.083213559068934e-05,
#  'let': 0.0002479093946577567,
#  'some': 0.0017411989248315382,
#  'robots': 1.5749538013551602e-05,
#  'acting': 0.0004054047747932727,
#  'below': 4.0248819367965205e-05,
#  'average': 6.941463050417187e-05,
#  'likes': 5.774830604968921e-05,
#  're': 0.0006603139641237191,
#  'likely': 9.566386052675788e-05,
#  'work': 0.0005949825471786161,
#  'halloween': 3.499897336344801e-05,
#  'h20': 4.083213559068934e-06,
#  'wasted': 6.883131428144774e-05,
#  'real': 0.0005337343437925821,
#  'star': 0.0004439036454930655,
#  'stan': 6.999794672689601e-06,
#  'winston': 2.3332648908965336e-06,
#  'robot': 2.6249230022586003e-05,
#  'design': 5.0748511376999607e-05,
#  'schnazzy': 5.833162227241334e-07,
#  'cgi': 2.916581113620667e-05,
#  'occasional': 3.616560580889627e-05,
#  'shot': 0.00020299404550799843,
#  'picking': 1.6332854236275736e-05,
#  'brain': 5.424840871334441e-05,
#  'if': 0.0016327021074048495,
#  'body': 0.00015691206391279188,
#  'parts': 0.00012074645810389562,
#  'turn': 0.00021174378884886044,
#  'otherwise': 9.099733074496482e-05,
#  'much': 0.0011952149403617494,
#  'sunken': 2.3332648908965336e-06,
#  'jaded': 6.999794672689601e-06,
#  'viewer': 0.00012716293655386108,
#  'thankful': 4.083213559068934e-06,
#  'invention': 6.416478449965468e-06,
#  'timex': 5.833162227241334e-07,
#  'indiglo': 5.833162227241334e-07,
#  'based': 0.0002269100106396879,
#  'late': 0.00013882926100834374,
#  '1960': 1.2832956899930936e-05,
#  'television': 0.00012832956899930936,
#  'show': 0.00043223732103858285,
#  'name': 0.00022865995930786032,
#  'mod': 9.916375786310269e-06,
#  'squad': 2.3332648908965335e-05,
#  'tells': 0.00014874563679465402,
#  'tale': 0.00012599630410841281,
#  'three': 0.0004054047747932727,
#  'reformed': 4.083213559068934e-06,
#  'criminals': 2.041606779534467e-05,
#  'under': 0.0002094105239579639,
#  'employ': 9.333059563586135e-06,
#  'police': 0.00014057920967651616,
#  'undercover': 1.6332854236275736e-05,
#  'however': 0.000576899744274168,
#  'wrong': 0.00022457674574879137,
#  'evidence': 3.8498870699792806e-05,
#  'gets': 0.0005045685326563754,
#  'stolen': 3.383234091799974e-05,
#  'immediately': 9.508054430403375e-05,
#  'suspicion': 1.1083008231758535e-05,
#  'ads': 1.9249435349896403e-05,
#  'cuts': 3.499897336344801e-05,
#  'claire': 4.083213559068934e-05,
#  'dane': 2.916581113620667e-06,
#  'nice': 0.0002006607806171019,
#  'hair': 6.358146827693054e-05,
#  'cute': 7.816437384503387e-05,
#  'outfits': 1.2249640677206802e-05,
#  'car': 0.00018724450749444684,
#  'chases': 2.916581113620667e-05,
#  'stuff': 0.00012132977432661975,
#  'blowing': 1.516622179082747e-05,
#  'sounds': 7.758105762230974e-05,
#  'first': 0.001070968584921509,
#  'fifteen': 3.733223825434454e-05,
#  'quickly': 0.00014874563679465402,
#  'becomes': 0.0003068243331528942,
#  'apparent': 5.833162227241334e-05,
#  'certainly': 0.00021057715640341215,
#  'slick': 2.2749332686241205e-05,
#  'looking': 0.00029224142758479087,
#  'complete': 0.00011491329587665429,
#  'costumes': 4.1415451813413474e-05,
#  'isn': 0.0005080684299927202,
#  'enough': 0.0005308177626789614,
#  'best': 0.0007775605248912698,
#  'described': 3.32490246952756e-05,
#  'cross': 6.474810072237881e-05,
#  'between': 0.0005629001549287887,
#  'hour': 0.00020707725906706737,
#  'long': 0.00048765236219737554,
#  'cop': 0.00012132977432661975,
#  'stretched': 1.1083008231758535e-05,
#  'span': 1.1083008231758535e-05,
#  'single': 0.00013941257723106788,
#  'clich': 4.1998768036137605e-05,
#  'matter': 0.00018724450749444684,
#  'elements': 0.00013766262856289548,
#  'recycled': 1.3999589345379203e-05,
#  'everything': 0.0003091575980437907,
#  'already': 0.00016857838836727455,
#  'seen': 0.0005308177626789614,
#  'nothing': 0.0004689862430702033,
#  'spectacular': 4.841524648610308e-05,
#  'sometimes': 0.00016157859369458495,
#  'bordering': 3.4998973363448007e-06,
#  'wooden': 2.7999178690758405e-05,
#  'danes': 1.516622179082747e-05,
#  'omar': 6.999794672689601e-06,
#  'epps': 9.333059563586135e-06,
#  'deliver': 5.3665092490620274e-05,
#  'their': 0.0018211132473447446,
#  'lines': 0.00018666119127172268,
#  'bored': 4.841524648610308e-05,
#  'transfers': 1.7499486681724003e-06,
#  'onto': 6.941463050417187e-05,
#  'escape': 9.216396319041308e-05,
#  'relatively': 3.8498870699792806e-05,
#  'unscathed': 4.666529781793067e-06,
#  'giovanni': 8.166427118137868e-06,
#  'ribisi': 1.3999589345379203e-05,
#  'plays': 0.00043865379948854834,
#  'resident': 4.666529781793067e-06,
#  'crazy': 5.774830604968921e-05,
#  'man': 0.0008143094469228902,
#  'ultimately': 9.216396319041308e-05,
#  'being': 0.0007804771060048905,
#  'worth': 0.00018607787504899855,
#  'watching': 0.00028757489780299777,
#  'unfortunately': 0.00022282679708061898,
#  'save': 0.00015924532880368843,
#  'convoluted': 1.8082802904448135e-05,
#  'apart': 6.883131428144774e-05,
#  'occupying': 2.916581113620667e-06,
#  'screen': 0.0004112379370205141,
#  'young': 0.00043340395348403116,
#  'cast': 0.0004485701752748586,
#  'clothes': 2.9749127358930804e-05,
#  'hip': 4.0248819367965205e-05,
#  'soundtrack': 8.633080096317175e-05,
#  'appears': 0.00014174584212196443,
#  'geared': 8.166427118137868e-06,
#  'towards': 0.00010616355253579229,
#  'teenage': 6.008157094058574e-05,
#  'mindset': 5.833162227241334e-06,
#  'r': 0.00010499692009034401,
#  'rating': 8.808074963134415e-05,
#  'content': 4.491534914975827e-05,
#  'justify': 1.3416273122655068e-05,
#  'juvenile': 1.2832956899930936e-05,
#  'older': 6.008157094058574e-05,
#  'information': 5.833162227241334e-05,
#  'literally': 6.183151960875815e-05,
#  'spoon': 1.2832956899930936e-05,
#  'hard': 0.00034240662273906633,
#  'instead': 0.0003295736658391354,
#  'telling': 7.758105762230974e-05,
#  'dialogue': 0.0003027411195938253,
#  'poorly': 5.483172493606854e-05,
#  'written': 0.00023857633509417057,
#  'extremely': 0.00014466242323558508,
#  'predictable': 0.00010616355253579229,
#  'progresses': 2.741586246803427e-05,
#  'won': 0.0001936609859444123,
#  'care': 0.00017732813170813656,
#  'heroes': 5.891493849513748e-05,
#  'any': 0.000918139734567786,
#  'jeopardy': 1.6332854236275736e-05,
#  'll': 0.00033657346051182497,
#  'aren': 0.0001516622179082747,
#  'basing': 2.3332648908965336e-06,
#  'nobody': 5.1331827599723744e-05,
#  'remembers': 5.2498460045172006e-06,
#  'questionable': 1.1666324454482668e-05,
#  'wisdom': 2.041606779534467e-05,
#  'especially': 0.0002659921975622048,
#  'considers': 1.1083008231758535e-05,
#  'target': 5.483172493606854e-05,
#  'fact': 0.00046956955929292743,
#  'number': 0.00012949620144475763,
#  'memorable': 8.574748474044761e-05,
#  'can': 0.0016811173538909526,
#  'counted': 7.583110895413735e-06,
#  'hand': 0.00022049353218972243,
#  'missing': 6.766468183599948e-05,
#  'finger': 1.4582905568103335e-05,
#  'times': 0.0003313236145073078,
#  'checked': 4.083213559068934e-06,
#  'six': 8.574748474044761e-05,
#  'clear': 0.00010733018498124055,
#  'indication': 6.416478449965468e-06,
#  'them': 0.0010948845500531985,
#  'than': 0.0014431243350195061,
#  'cash': 5.3665092490620274e-05,
#  'spending': 2.6832546245310137e-05,
#  'dollar': 3.208239224982734e-05,
#  'judging': 1.9832751572620537e-05,
#  'rash': 4.083213559068934e-06,
#  'awful': 7.699774139958561e-05,
#  'seeing': 0.00019774419950348122,
#  'avoid': 5.308177626789614e-05,
#  'at': 0.002908414686502529,
#  'costs': 1.4582905568103335e-05,
#  'quest': 4.0248819367965205e-05,
#  'camelot': 6.416478449965468e-06,
#  'warner': 2.7999178690758405e-05,
#  'bros': 1.3999589345379203e-05,
#  'feature': 0.0001341627312265507,
#  'length': 5.716498982696508e-05,
#  'fully': 5.949825471786161e-05,
#  'animated': 0.00010441360386761988,
#  'steal': 4.083213559068934e-05,
#  'clout': 5.2498460045172006e-06,
#  'disney': 0.0001691617045899987,
#  'cartoon': 5.1331827599723744e-05,
#  'empire': 2.391596513168947e-05,
#  'mouse': 2.9749127358930804e-05,
#  'reason': 0.0002549091893304463,
#  'worried': 1.691617045899987e-05,
#  'other': 0.001136300001866612,
#  'recent': 0.00012307972299479216,
#  'challenger': 1.1666324454482668e-06,
#  'throne': 1.0499692009034401e-05,
#  'last': 0.0004917355757564445,
#  'fall': 0.00013941257723106788,
#  'promising': 3.1499076027103203e-05,
#  'flawed': 2.858249491348254e-05,
#  '20th': 1.6332854236275736e-05,
#  'century': 7.058126294962015e-05,
#  'fox': 6.474810072237881e-05,
#  'anastasia': 1.2832956899930936e-05,
#  'hercules': 9.333059563586135e-06,
#  'lively': 1.866611912717227e-05,
#  'colorful': 2.9749127358930804e-05,
#  'palate': 2.3332648908965336e-06,
#  'had': 0.0009018068803315103,
#  'beat': 4.1415451813413474e-05,
#  'hands': 8.633080096317175e-05,
#  'crown': 8.749743340862002e-06,
#  '1997': 6.533141694510294e-05,
#  'piece': 0.00014232915834468856,
#  'animation': 8.283090362682695e-05,
#  'year': 0.0005168181733335822,
#  'contest': 1.3999589345379203e-05,
#  'arrival': 2.1582700240792936e-05,
#  'magic': 5.3665092490620274e-05,
#  'kingdom': 1.1083008231758535e-05,
#  'mediocre': 4.316540048158587e-05,
#  '--': 0.0010587189442443023,
#  'd': 0.0003517396823026525,
#  'pocahontas': 6.416478449965468e-06,
#  'those': 0.0005920659660649954,
#  'keeping': 5.1331827599723744e-05,
#  'score': 0.0001236630392175163,
#  'nearly': 0.00017907808037630896,
#  'dull': 7.816437384503387e-05,
#  'revolves': 3.033244358165494e-05,
#  'adventures': 3.091575980437907e-05,
#  'free': 9.274727941313721e-05,
#  'spirited': 2.5082597577137738e-05,
#  'kayley': 2.3332648908965336e-06,
#  'voiced': 3.32490246952756e-05,
#  'jessalyn': 5.833162227241334e-07,
#  'gilsig': 5.833162227241334e-07,
#  'early': 0.00017674481548541243,
#  'daughter': 0.0001849112426035503,
#  'belated': 1.1666324454482668e-06,
#  'knight': 2.1582700240792936e-05,
#  'king': 0.00014932895301737815,
#  'arthur': 2.6249230022586003e-05,
#  'round': 2.858249491348254e-05,
#  'table': 3.091575980437907e-05,
#  'dream': 9.566386052675788e-05,
#  'follow': 0.00010791350120396468,
#  'father': 0.00028699158158027364,
#  'footsteps': 9.916375786310269e-06,
#  'she': 0.001832196255576503,
#  'chance': 0.00013007951766748176,
#  'evil': 0.00025024265954865323,
#  'warlord': 1.7499486681724003e-06,
#  'ruber': 5.833162227241334e-07,
#  'gary': 4.491534914975827e-05,
#  'oldman': 1.9249435349896403e-05,
#  'ex': 9.624717674948201e-05,
#  'gone': 0.00011374666343120601,
#  'steals': 3.441565714072387e-05,
#  'magical': 2.9749127358930804e-05,
#  'sword': 2.5665913799861872e-05,
#  'excalibur': 1.7499486681724003e-06,
#  'accidentally': 3.32490246952756e-05,
#  'loses': 4.958187893155134e-05,
#  'dangerous': 4.724861404065481e-05,
#  'booby': 2.3332648908965336e-06,
#  'trapped': 3.033244358165494e-05,
#  'forest': 2.6249230022586003e-05,
#  'help': 0.00031324081160285963,
#  'hunky': 6.999794672689601e-06,
#  'blind': 2.5665913799861872e-05,
#  'timberland': 1.1666324454482668e-06,
#  'dweller': 1.1666324454482668e-06,
#  'garrett': 5.2498460045172006e-06,
#  'carey': 7.583110895413735e-06,
#  'elwes': 3.4998973363448007e-06,
#  'headed': 4.3748716704310004e-05,
#  'dragon': 3.266570847255147e-05,
#  'eric': 3.733223825434454e-05,
#  'idle': 1.3416273122655068e-05,
#  'rickles': 2.3332648908965336e-06,
#  'arguing': 9.916375786310269e-06,
#  'itself': 0.00023857633509417057,
#  'able': 0.00019774419950348122,
#  'medieval': 9.916375786310269e-06,
#  'sexist': 8.166427118137868e-06,
#  'prove': 5.949825471786161e-05,
#  'fighter': 1.866611912717227e-05,
#  'side': 0.0001989108319489295,
#  'pure': 5.2498460045172006e-05,
#  'showmanship': 2.3332648908965336e-06,
#  'essential': 1.9832751572620537e-05,
#  'element': 8.749743340862001e-05,
#  'expected': 8.049763873593041e-05,
#  'climb': 9.333059563586135e-06,
#  'high': 0.0003639893229798593,
#  'ranks': 1.3999589345379203e-05,
#  'differentiates': 1.1666324454482668e-06,
#  'something': 0.0006188985123103056,
#  'saturday': 3.091575980437907e-05,
#  'morning': 3.8498870699792806e-05,
#  'subpar': 1.7499486681724003e-06,
#  'instantly': 2.391596513168947e-05,
#  'forgettable': 1.7499486681724004e-05,
#  'songs': 6.941463050417187e-05,
#  'integrated': 4.083213559068934e-06,
#  'computerized': 2.3332648908965336e-06,
#  'footage': 6.066488716330988e-05,
#  'compare': 2.391596513168947e-05,
#  'run': 0.00020649394284434324,
#  'angry': 5.1915143822447875e-05,
#  'ogre': 1.1666324454482668e-05,
#  'herc': 1.1666324454482668e-06,
#  'battle': 0.0001341627312265507,
#  'hydra': 1.1666324454482668e-06,
#  'rest': 0.0002514092919941015,
#  'case': 0.00024499281354413606,
#  'stink': 2.916581113620667e-06,
#  'none': 0.0001411625258992403,
#  'remotely': 2.916581113620667e-05,
#  'interesting': 0.0003721557500979971,
#  'race': 7.408116028596495e-05,
#  'bland': 4.899856270882721e-05,
#  'end': 0.0006194818285330297,
#  'tie': 1.9832751572620537e-05,
#  'win': 6.533141694510294e-05,
#  'comedy': 0.0004899856270882721,
#  'shtick': 8.166427118137868e-06,
#  'awfully': 1.5749538013551602e-05,
#  'cloying': 2.916581113620667e-06,
#  'least': 0.0003943217665615142,
#  'signs': 3.091575980437907e-05,
#  'pulse': 1.3416273122655068e-05,
#  'fans': 0.0001429124745674127,
#  "-'": 1.7499486681724003e-06,
#  '90s': 2.391596513168947e-05,
#  'tgif': 1.1666324454482668e-06,
#  'will': 0.0012926287495566796,
#  'thrilled': 8.749743340862002e-06,
#  'jaleel': 5.833162227241334e-07,
#  'urkel': 1.1666324454482668e-06,
#  'white': 0.0001831612939353779,
#  'bronson': 1.1666324454482668e-05,
#  'balki': 5.833162227241334e-07,
#  'pinchot': 1.1666324454482668e-06,
#  'sharing': 8.166427118137868e-06,
#  'nicely': 5.716498982696508e-05,
#  'realized': 5.1331827599723744e-05,
#  'though': 0.0005483172493606854,
#  'm': 0.000424070893920445,
#  'loss': 3.1499076027103203e-05,
#  'recall': 3.033244358165494e-05,
#  'specific': 2.0999384018068802e-05,
#  'providing': 2.6832546245310137e-05,
#  'voice': 0.0001604119612491367,
#  'talent': 0.00013007951766748176,
#  'enthusiastic': 1.0499692009034401e-05,
#  'paired': 5.2498460045172006e-06,
#  'singers': 5.833162227241334e-06,
#  'sound': 0.0001429124745674127,
#  'musical': 8.983069829951654e-05,
#  'moments': 0.00026074235155768764,
#  'jane': 4.841524648610308e-05,
#  'seymour': 4.666529781793067e-06,
#  'celine': 5.833162227241334e-06,
#  'dion': 1.1666324454482668e-06,
#  'must': 0.00036048942564351444,
#  'strain': 8.166427118137868e-06,
#  'through': 0.0006941463050417187,
#  'aside': 6.883131428144774e-05,
#  'children': 0.00019599425083530883,
#  'probably': 0.0003144074440483079,
#  'adults': 4.958187893155134e-05,
#  'grievous': 1.7499486681724003e-06,
#  'error': 8.749743340862002e-06,
#  'lack': 0.00013824594478561961,
#  'personality': 6.766468183599948e-05,
#  'learn': 0.00010033039030855095,
#  'goes': 0.0003768222798797902,
#  'synopsis': 3.908218692251694e-05,
#  'mentally': 2.1582700240792936e-05,
#  'unstable': 8.749743340862002e-06,
#  'undergoing': 1.7499486681724003e-06,
#  'psychotherapy': 1.1666324454482668e-06,
#  'saves': 2.5082597577137738e-05,
#  'boy': 0.0002111604726261363,
#  'potentially': 2.2749332686241205e-05,
#  'fatal': 2.2749332686241205e-05,
#  'falls': 0.00013941257723106788,
#  'love': 0.0006527308532283053,
#  'mother': 0.0002549091893304463,
#  'fledgling': 4.083213559068934e-06,
#  'restauranteur': 1.1666324454482668e-06,
#  'unsuccessfully': 5.2498460045172006e-06,
#  'attempting': 3.208239224982734e-05,
#  'gain': 2.4499281354413604e-05,
#  'woman': 0.0003231571873891699,
#  'favor': 2.741586246803427e-05,
#  'takes': 0.0003931551341160659,
#  'pictures': 6.824799805872361e-05,
#  'kills': 4.549866537248241e-05,
#  'comments': 3.091575980437907e-05,
#  'stalked': 1.3416273122655068e-05,
#  'yet': 0.00035465626341627313,
#  'seemingly': 7.233121161779254e-05,
#  'endless': 3.32490246952756e-05,
#  'string': 2.2749332686241205e-05,
#  'spurned': 2.3332648908965336e-06,
#  'psychos': 2.3332648908965336e-06,
#  'getting': 0.00023682638642599817,
#  'revenge': 5.833162227241334e-05,
#  'type': 0.00012482967166296455,
#  'stable': 8.749743340862002e-06,
#  'category': 2.3332648908965335e-05,
#  '1990s': 1.3416273122655068e-05,
#  'industry': 5.0748511376999607e-05,
#  'theatrical': 3.558228958617214e-05,
#  'direct': 4.491534914975827e-05,
#  'proliferation': 1.7499486681724003e-06,
#  'may': 0.0004999020028745824,
#  'due': 0.00011432997965393016,
#  'typically': 1.6332854236275736e-05,
#  'inexpensive': 1.7499486681724003e-06,
#  'produce': 2.5665913799861872e-05,
#  'special': 0.0003348235118436526,
#  'effects': 0.0003785722285479626,
#  'stars': 0.00023274317286692923,
#  'serve': 4.608198159520654e-05,
#  'vehicles': 1.4582905568103335e-05,
#  'nudity': 4.258208425886174e-05,
#  'allowing': 2.4499281354413604e-05,
#  'frequent': 2.041606779534467e-05,
#  'night': 0.000253742556884998,
#  'cable': 2.858249491348254e-05,
#  'wavers': 5.833162227241334e-07,
#  'slightly': 8.808074963134415e-05,
#  'norm': 1.516622179082747e-05,
#  'respect': 5.3665092490620274e-05,
#  'psycho': 3.558228958617214e-05,
#  'never': 0.0008014764900229594,
#  'affair': 5.599835738151681e-05,
#  ';': 0.0010791350120396468,
#  'contrary': 1.5749538013551602e-05,
#  'rejected': 1.1083008231758535e-05,
#  'rather': 0.0003622393743116869,
#  'lover': 5.483172493606854e-05,
#  'wife': 0.00034298993896179046,
#  'husband': 0.0001516622179082747,
#  'entry': 2.6249230022586003e-05,
#  'doomed': 1.691617045899987e-05,
#  'collect': 1.1083008231758535e-05,
#  'dust': 1.2249640677206802e-05,
#  'viewed': 2.6249230022586003e-05,
#  'midnight': 2.916581113620667e-05,
#  'provide': 7.349784406324081e-05,
#  'suspense': 0.00011782987699027496,
#  'sets': 0.00014057920967651616,
#  'interspersed': 2.916581113620667e-06,
#  'opening': 0.00017849476415358483,
#  'credits': 0.00011841319321299909,
#  'instance': 4.3748716704310004e-05,
#  'serious': 0.00012599630410841281,
#  'sounding': 1.9832751572620537e-05,
#  'narrator': 2.1582700240792936e-05,
#  'spouts': 2.3332648908965336e-06,
#  'statistics': 5.833162227241334e-07,
#  'stalkers': 1.1666324454482668e-06,
#  'ponders': 4.083213559068934e-06,
#  'cause': 5.716498982696508e-05,
#  'stalk': 2.3332648908965336e-06,
#  'implicitly': 1.7499486681724003e-06,
#  'implied': 5.2498460045172006e-06,
#  'men': 0.000310324230489239,
#  'shown': 7.641442517686148e-05,
#  'snapshot': 5.833162227241334e-07,
#  'actor': 0.00031849065760737686,
#  'jay': 5.833162227241334e-05,
#  'underwood': 6.416478449965468e-06,
#  'states': 6.416478449965468e-05,
#  'daryl': 1.3999589345379203e-05,
#  'gleason': 1.1666324454482668e-06,
#  'stalker': 5.833162227241334e-06,
#  'brooke': 7.583110895413735e-06,
#  'daniels': 1.5749538013551602e-05,
#  'meant': 5.308177626789614e-05,
#  'called': 0.00022807664308513616,
#  'guesswork': 5.833162227241334e-07,
#  'required': 3.091575980437907e-05,
#  'proceeds': 1.691617045899987e-05,
#  'begins': 0.00022865995930786032,
#  'obvious': 0.00017032833703544697,
#  'sequence': 0.00021349373751703283,
#  'contrived': 4.491534914975827e-05,
#  'quite': 0.00038498870699792804,
#  'brings': 0.00011782987699027496,
#  'victim': 6.591473316782707e-05,
#  'together': 0.00030449106826199767,
#  'obsesses': 2.3332648908965336e-06,
#  'follows': 9.916375786310268e-05,
#  'tries': 0.00021582700240792936,
#  'woo': 5.483172493606854e-05,
#  'plans': 5.2498460045172006e-05,
#  'become': 0.0002980745898120322,
#  'desperate': 5.891493849513748e-05,
#  'elaborate': 3.674892203162041e-05,
#  'include': 6.416478449965468e-05,
#  'cliche': 3.7915554477068676e-05,
#  'murdered': 3.208239224982734e-05,
#  'pet': 2.3332648908965335e-05,
#  'require': 2.0999384018068802e-05,
#  'found': 0.0002321598566442051,
#  'exception': 5.949825471786161e-05,
#  'cat': 3.441565714072387e-05,
#  'shower': 1.8082802904448135e-05,
#  'events': 0.00011724656076755083,
#  'lead': 0.0001464123719037575,
#  'inevitable': 4.083213559068934e-05,
#  'showdown': 2.1582700240792936e-05,
#  'survives': 1.1666324454482668e-05,
#  'invariably': 3.4998973363448007e-06,
#  'conclusion': 7.116457917234428e-05,
#  'turkey': 2.3332648908965335e-05,
#  'uniformly': 8.749743340862002e-06,
#  'adequate': 2.216601646351707e-05,
#  'anything': 0.00036048942564351444,
#  'home': 0.0003208239224982734,
#  'either': 0.0002251600619715155,
#  'turns': 0.00023507643775782578,
#  'toward': 5.833162227241334e-05,
#  'melodrama': 2.0999384018068802e-05,
#  'overdoes': 2.3332648908965336e-06,
#  'words': 0.00012541298788568868,
#  'manages': 0.00014466242323558508,
#  'creepy': 5.424840871334441e-05,
#  'pass': 5.716498982696508e-05,
#  'demands': 2.5665913799861872e-05,
#  'maryam': 5.833162227241334e-07,
#  'abo': 1.7499486681724003e-06,
#  'close': 0.00016857838836727455,
#  'played': 0.00046140313217478955,
#  'bond': 9.041401452224067e-05,
#  'chick': 1.9249435349896403e-05,
#  'living': 0.00013649599611744722,
#  'daylights': 5.833162227241334e-07,
#  'equally': 6.416478449965468e-05,
#  'title': 0.00017324491814906762,
#  'ditzy': 8.166427118137868e-06,
#  'strong': 0.00015632874769006775,
#  'independent': 2.6249230022586003e-05,
#  'business': 0.00011258003098575775,
#  'owner': 5.774830604968921e-05,
#  'needs': 0.0001289128852220335,
#  'proceed': 1.516622179082747e-05,
#  'example': 0.00017499486681724001,
#  'suspicions': 2.916581113620667e-06,
#  'ensure': 8.749743340862002e-06,
#  'use': 0.0002321598566442051,
#  'excuse': 4.3748716704310004e-05,
#  'decides': 0.00011024676609486122,
#  'return': 0.00011374666343120601,
#  'toolbox': 1.1666324454482668e-06,
#  ...}

# %% [markdown]
# -----
#
# #### 第四步：定义生成候选词集合的函数。对于词库里没有的词，取编辑距离为1和2，生成候选词集合；

# %%
def generate_edit_one(word : str):
    # the first list is used for generating candidates words whose distance are two from the original word
    # the second list is used to store words whose distance are one from the original word
    alphabet = ''
    for i in range(ord('a'), ord('z')):
        alphabet += chr(i)
    split = []
    for i in range(len(word) + 1):
        split.append((word[: i], word[i :]))

    # 距离为1 分别是插入 删除 替换
    insert1 = [L + letter + R for L,R in split for letter in alphabet]
    delete1 = [L + R[1 :] for L,R in split]
    replace1 = [L + letter + R[1 :] for L,R in split for letter in alphabet]

    # 去重 并选出存在于词典的词
    dis_1 = list(set(insert1 + delete1 + replace1))
    distance_1 = []
    for word1 in dis_1:
        if word1 in vocab:
            distance_1.append(word1)
    distance_1 = set(distance_1).difference(set(word))
    return dis_1, distance_1

def generate_edit_two(word : str) -> list:
    alphabet = ''
    for i in range(ord('a'), ord('z')):
        alphabet += chr(i)
    dis_1, distance_1 = generate_edit_one(word)

    # 距离为2 
    # 需要主力这里split要对dis_1处理
    # 也就是说在距离为1的所有可能上进行距离2的进一步预测
    split = []
    for j in range(len(dis_1)):
        for i in range(len(dis_1[j]) + 1):
            split.append((dis_1[j][: i], dis_1[j][i :]))

    insert2 = [L + letter + R for L,R in split for letter in alphabet]
    delete2 = [L + R[1 :] for L,R in split]
    replace2 = [L + letter + R[1 :] for L,R in split for letter in alphabet]
    dis_2 = set(insert2 + delete2 + replace2)
    distance_2 = []
    for word2 in dis_2:
        if word2 in vocab:
            distance_2.append(word2)
    #print(len(distance_1), len(distance_2))
    # 距离为2的字一定包含距离为1的字，因为replace换相同字母相当于没换
    # 所以这里不再需要 distance_2 + distance_1再去重
    distance_1 = set(distance_2).difference(set(word)) 
    # 这里去掉word本身，不去也可以 
    # 个人认为如果去掉word本身，要进行“存在词但不符合前后文”的纠错的时候
    # 可以设置一个值域来判定是否替换
    return distance_2

    # 看到了个别的写法
    # return set([e2 for e1 in generate_edit_one(word) 
    #       for e2 in generate_edit_one(e1) 
    #       if e2 in vocab])

a = generate_edit_two('wolrd')
print(len(a))
# Out:
# 39

# %% [markdown]
# -----
#
# #### 第五步：读取testdata.txt，找出拼错词，生成候选词，并计算每个候选词的概率； 选出概率最高的候选词，作为修改词。
#
# >*为避免文件过大，输出前100句结果即可。*

# %%
import numpy as np
import math
import re

mistake_word_num = 0
with open('./data/hw4-data-testdata.txt') as file:
    for line in file:
        items = line.split('\t')
        n=items[0]
        word_list = items[2].split()

        # 去掉标点，避免匹配问题
        for index, word in enumerate(word_list):
            word_list[index] = re.sub("[.,]", "", word)
        


        if int(n) > 100:
            break
        for index, word in enumerate(word_list):
            #word = word.strip(',.') 前面消除了
            if word not in vocab:
                print("第",n,"句：")
                mistake_word_num += 1


                # 先生成编辑距离1的候选词，找不到候选词时再生成编辑距离2的候选词
                candidates = generate_edit_one(word) # 前面实现的时候返回元组
                candidates = candidates[1]

                if len(candidates) == 0:
                    # 同时生成编辑距离1和2的候选词
                    # 这里前面的算法实现的时候已经将 1 包含在 2 中了
                    candidates =  generate_edit_two(word) 

                if len(candidates) == 0:
                    print("没有合适的修改词")
                    continue
                # print(candidates)

                # 对于每一个candidate, 计算它的prob
                # prob = p(correct)*p(mistake|correct)
                #       = log p(correct) + log p(mistake|correct)
                # 返回prob最大的candidate
                max_pro = -1e6
                chosen = ''
                can_with_prob = {}

                for candi in candidates:
                    prob = 0.0
                    # candi 是正确词， word是错误词，应使用mispell数组
                    
                    if candi in misspell_prob and word in misspell_prob[candi] :
                        prob += math.log(misspell_prob[candi][word])
                    else:
                        #prob -= 1e4 # 没有这个词要降低权重
                        prob += math.log(1.0 / (len(misspell_prob) + len(vocab))) 
                        #减常数过于粗暴试了试平滑
                        # 不过想了下，平滑本质还是一个常数
                    
                    # 下面处理bi模型
                        
                    #print(word_list)
                    idx = word_list.index(word)
                    bi_word = " " + candi
                    pre = ""
                

                    # 前一个单词加
                    if idx > 0:
                        pre = word_list[idx - 1]
                    else:
                        pre = start # '(START)'
                    bi_word = pre + bi_word
                    # print(bigram[bi_word] + 1.0)
                    # print(words[pre] + word_cnt)

                    if bi_word in bigrams and pre in words:
                        prob += math.log( (bigrams[bi_word] + 1.0)
                        / (words[pre] + word_cnt) )
                    else:
                        #prob -= 1e4
                        prob += math.log(1.0 / (word_cnt))
                    
                    if prob > max_pro:
                        max_pro = prob
                        chosen = candi
                    can_with_prob[candi] = prob
                print("候选词集合", can_with_prob)
                print("错误词为 "+ word +" 候选词为 ", chosen, "评分为：", max_pro)
# Out:
# 第 1 句：
# 候选词集合 {'protectionist': -25.28885691038303}
# 错误词为 protectionst 候选词为  protectionist 评分为： -25.28885691038303
# 第 2 句：
# 没有合适的修改词
# 第 3 句：
# 候选词集合 {'retaliation': -25.288855098611428}
# 错误词为 retaiation 候选词为  retaliation 评分为： -25.288855098611428
# 第 3 句：
# 候选词集合 {'Japan': -25.28885691038303, 'Japanese': -25.28885691038303}
# 错误词为 Japan's 候选词为  Japan 评分为： -25.28885691038303
# 第 4 句：
# 候选词集合 {'gases': -25.28885691038303, 'cases': -25.28885691038303, 'bases': -25.28885691038303, 'vases': -25.28885691038303, 'taxes': -25.28885691038303, 'tapes': -25.28885691038303, 'tasks': -25.28885691038303, 'takes': -25.28885630442337, 'tastes': -25.28885691038303, 'tales': -25.28885691038303, 'oases': -25.28885691038303}
# 错误词为 tases 候选词为  takes 评分为： -25.28885630442337
# 第 5 句：
# 没有合适的修改词
# 第 5 句：
# 候选词集合 {'business': -25.288855698236446}
# 错误词为 busines 候选词为  business 评分为： -25.288855698236446
# 第 5 句：
# 没有合适的修改词
# 第 7 句：
# 候选词集合 {'Taiwan': -25.28885691038303, 'Train': -25.28885691038303, 'Twain': -25.28885691038303, 'Tanin': -25.28885691038303}
# 错误词为 Taawin 候选词为  Taiwan 评分为： -25.28885691038303
# 第 8 句：
# 候选词集合 {'seriousness': -25.288855723624444}
# 错误词为 seriousnyss 候选词为  seriousness 评分为： -25.288855723624444
# 第 9 句：
# 候选词集合 {'against': -16.146295860828136}
# 错误词为 aganst 候选词为  against 评分为： -16.146295860828136
# 第 10 句：
# 候选词集合 {'silicon': -25.28885691038303, 'billion': -25.28885691038303}
# 错误词为 bililon 候选词为  silicon 评分为： -25.28885691038303
# 第 11 句：
# 候选词集合 {'sell': -25.28885691038303}
# 错误词为 sewll 候选词为  sell 评分为： -25.28885691038303
# 第 11 句：
# 候选词集合 {'Taiwanese': -25.28885691038303, 'Taiwan': -25.28885691038303}
# 错误词为 Taiwan's 候选词为  Taiwanese 评分为： -25.28885691038303
# 第 11 句：
# 候选词集合 {'worlds': -25.28885451082774}
# 错误词为 world's 候选词为  worlds 评分为： -25.28885451082774
# 第 12 句：
# 候选词集合 {'imports': -25.28885691038303}
# 错误词为 importsi 候选词为  imports 评分为： -25.28885691038303
# 第 13 句：
# 候选词集合 {'Sheep': -25.28885691038303, 'Sheen': -25.28885691038303, 'Sheer': -25.28885691038303}
# 错误词为 Sheem 候选词为  Sheep 评分为： -25.28885691038303
# 第 14 句：
# 候选词集合 {'Koreans': -25.28885691038303}
# 错误词为 Korea's 候选词为  Koreans 评分为： -25.28885691038303
# 第 14 句：
# 候选词集合 {'soe': -25.28885691038303, 'whose': -25.28885691038303, 'woke': -25.28885691038303, 'woe': -25.28885691038303, 'some': -25.28885691038303, 'wohd': -25.28885691038303, 'sole': -25.28885691038303, 'wove': -25.28885691038303, 'wore': -25.28885691038303, 'whole': -25.28885691038303, 'whoe': -25.28885691038303, 'wrote': -25.28885691038303, 'whore': -25.28885691038303, 'she': -25.28885691038303, 'sore': -25.28885691038303}
# 错误词为 wsohe 候选词为  soe 评分为： -25.28885691038303
# 第 15 句：
# 候选词集合 {'Korea': -25.28885691038303}
# 错误词为 Koreva 候选词为  Korea 评分为： -25.28885691038303
# 第 16 句：
# 候选词集合 {'Japs': -25.28885691038303, 'Japan': -25.28885691038303, 'Jan': -25.28885691038303}
# 错误词为 Japn 候选词为  Japs 评分为： -25.28885691038303
# 第 17 句：
# 候选词集合 {'semiconductors': -25.28885691038303}
# 错误词为 semicondctors 候选词为  semiconductors 评分为： -25.28885691038303
# 第 18 句：
# 候选词集合 {'advantage': -25.28885691038303}
# 错误词为 advantagne 候选词为  advantage 评分为： -25.28885691038303
# 第 19 句：
# 候选词集合 {'Lawrence': -25.28885691038303}
# 错误词为 Lawrenc 候选词为  Lawrence 评分为： -25.28885691038303
# 第 21 句：
# 候选词集合 {'disadvantage': -25.28885633002335}
# 错误词为 disadxantage 候选词为  disadvantage 评分为： -25.28885633002335
# 第 22 句：
# 候选词集合 {'Kong': -25.28885691038303, 'longs': -25.28885691038303, 'tongs': -25.28885691038303, 'songs': -25.28885691038303, 'Kings': -25.28885691038303}
# 错误词为 Kong's 候选词为  Kong 评分为： -25.28885691038303
# 第 22 句：
# 候选词集合 {'export': -25.28885691038303, 'report': -25.28885691038303, 'poet': -25.28885691038303}
# 错误词为 rxpoet 候选词为  export 评分为： -25.28885691038303
# 第 22 句：
# 候选词集合 {'poets': -25.28885691038303, 'reports': -25.28885691038303, 'exports': -25.28885691038303}
# 错误词为 rxpoets 候选词为  poets 评分为： -25.28885691038303
# 第 23 句：
# 候选词集合 {'concern': -25.28885570968987}
# 错误词为 conceern 候选词为  concern 评分为： -25.28885570968987
# 第 24 句：
# 候选词集合 {'sitter': -25.28885691038303, 'gutter': -25.28885691038303, 'butter': -25.28885691038303, 'bitter': -25.28885691038303, 'patter': -25.28885691038303, 'better': -25.28885691038303, 'meter': -25.28885691038303, 'otter': -25.28885691038303, 'putter': -25.28885691038303, 'batter': -25.28885691038303, 'alter': -25.28885691038303, 'letter': -25.28885691038303, 'amateur': -25.28885691038303, 'litter': -25.28885691038303, 'cutter': -25.28885691038303, 'after': -25.28885691038303, 'utter': -25.28885691038303, 'fatter': -25.28885691038303, 'latter': -25.28885691038303, 'cotter': -25.28885691038303, 'matter': -25.28885691038303, 'titter': -25.28885691038303, 'mutter': -25.28885691038303, 'miter': -25.28885691038303, 'mater': -25.28885691038303, 'amber': -25.28885691038303, 'hitter': -25.28885691038303, 'hotter': -25.28885691038303}
# 错误词为 amtter 候选词为  sitter 评分为： -25.28885691038303
# 第 25 句：
# 候选词集合 {'Australia': -25.28885691038303, 'Australian': -25.28885691038303, 'Australites': -25.28885691038303}
# 错误词为 Australia's 候选词为  Australia 评分为： -25.28885691038303
# 第 25 句：
# 候选词集合 {'centred': -25.28885691038303}
# 错误词为 cenntred 候选词为  centred 评分为： -25.28885691038303
# 第 25 句：
# 候选词集合 {'Australia': -25.28885691038303, 'Australian': -25.28885691038303, 'Australites': -25.28885691038303}
# 错误词为 Australia's 候选词为  Australia 评分为： -25.28885691038303
# 第 26 句：
# 没有合适的修改词
# 第 26 句：
# 候选词集合 {'tread': -25.28885691038303, 'trap': -25.288853904429942, 'toad': -25.28885691038303, 'brad': -25.28885691038303, 'grad': -25.28885633002335, 'tray': -25.28885691038303, 'triad': -25.28885633002335, 'trade': -15.047675108643286}
# 错误词为 trad 候选词为  trade 评分为： -15.047675108643286
# 第 27 句：
# 候选词集合 {'Japan': -25.28885691038303, 'Japanese': -25.28885691038303}
# 错误词为 Japan's 候选词为  Japan 评分为： -25.28885691038303
# 第 27 句：
# 候选词集合 {'Liberals': -25.28885691038303, 'Liberal': -25.28885691038303}
# 错误词为 Liberala 候选词为  Liberals 评分为： -25.28885691038303
# 第 28 句：
# 候选词集合 {'include': -25.28885691038303}
# 错误词为 inoclude 候选词为  include 评分为： -25.28885691038303
# 第 29 句：
# 候选词集合 {'Nakasone': -25.28885691038303}
# 错误词为 Nakasone's 候选词为  Nakasone 评分为： -25.28885691038303
# 第 29 句：
# 候选词集合 {'filial': -25.28885691038303, 'facial': -25.28885691038303, 'finial': -25.28885691038303, 'fiscal': -25.28885691038303}
# 错误词为 fcsial 候选词为  filial 评分为： -25.28885691038303
# 第 30 句：
# 候选词集合 {'Representative': -25.28885691038303}
# 错误词为 Representetive 候选词为  Representative 评分为： -25.28885691038303
# 第 30 句：
# 候选词集合 {'Japan': -25.28885691038303, 'Japanese': -25.28885691038303}
# 错误词为 Japan's 候选词为  Japan 评分为： -25.28885691038303
# 第 31 句：
# 候选词集合 {'157': -25.28885691038303, '175': -25.28885691038303, '155': -25.28885691038303}
# 错误词为 1575 候选词为  157 评分为： -25.28885691038303
# 第 31 句：
# 候选词集合 {'China': -25.28885691038303}
# 错误词为 China's 候选词为  China 评分为： -25.28885691038303
# 第 31 句：
# 候选词集合 {'output': -25.28885691038303}
# 错误词为 ootput 候选词为  output 评分为： -25.28885691038303
# 第 32 句：
# 候选词集合 {'methods': -25.28885691038303}
# 错误词为 methids 候选词为  methods 评分为： -25.28885691038303
# 第 33 句：
# 候选词集合 {'production': -25.28885691038303}
# 错误词为 producton 候选词为  production 评分为： -25.28885691038303
# 第 34 句：
# 候选词集合 {'pare': -25.28885691038303, 'prep': -25.28885691038303}
# 错误词为 parep 候选词为  pare 评分为： -25.28885691038303
# 第 35 句：
# 候选词集合 {'energy': -25.28885691038303}
# 错误词为 endergy 候选词为  energy 评分为： -25.28885691038303
# 第 36 句：
# 候选词集合 {'Japanese': -25.28885691038303}
# 错误词为 Japnese 候选词为  Japanese 评分为： -25.28885691038303
# 第 37 句：
# 候选词集合 {'Agency': -25.28885691038303}
# 错误词为 Agencay 候选词为  Agency 评分为： -25.28885691038303
# 第 38 句：
# 候选词集合 {'energy': -25.288848432437316}
# 错误词为 energyr 候选词为  energy 评分为： -25.288848432437316
# 第 39 句：
# 候选词集合 {'provided': -25.28885691038303}
# 错误词为 pfovided 候选词为  provided 评分为： -25.28885691038303
# 第 39 句：
# 候选词集合 {'Japan': -25.28885691038303, 'Japanese': -25.28885691038303}
# 错误词为 Japan's 候选词为  Japan 评分为： -25.28885691038303
# 第 40 句：
# 候选词集合 {'imports': -25.28885691038303}
# 错误词为 imhorts 候选词为  imports 评分为： -25.28885691038303
# 第 40 句：
# 候选词集合 {'61': -25.28885691038303, '65': -25.28885691038303, '51': -25.28885691038303}
# 错误词为 651 候选词为  61 评分为： -25.28885691038303
# 第 40 句：
# 候选词集合 {'87': -25.28885691038303, '58': -25.28885691038303, '57': -25.28885691038303}
# 错误词为 587 候选词为  87 评分为： -25.28885691038303
# 第 41 句：
# 候选词集合 {'Thailand': -25.28885691038303}
# 错误词为 Thailand's 候选词为  Thailand 评分为： -25.28885691038303
# 第 41 句：
# 候选词集合 {'increase': -25.28885691038303, 'incense': -25.28885691038303}
# 错误词为 incease 候选词为  increase 评分为： -25.28885691038303
# 第 42 句：
# 候选词集合 {'country': -25.28885691038303, 'countries': -25.28885691038303}
# 错误词为 country's 候选词为  country 评分为： -25.28885691038303
# 第 42 句：
# 候选词集合 {'quarter': -25.288856304608473, 'quartet': -25.28885691038303}
# 错误词为 quartee 候选词为  quarter 评分为： -25.288856304608473
# 第 43 句：
# 候选词集合 {'expanded': -25.28885691038303}
# 错误词为 expanted 候选词为  expanded 评分为： -25.28885691038303
# 第 44 句：
# 候选词集合 {'Export': -25.28885691038303}
# 错误词为 Exeport 候选词为  Export 评分为： -25.28885691038303
# 第 45 句：
# 候选词集合 {'clothing': -25.28885691038303}
# 错误词为 clotcing 候选词为  clothing 评分为： -25.28885691038303
# 第 46 句：
# 候选词集合 {'argued': -25.28885691038303, 'around': -25.28885691038303}
# 错误词为 arnuod 候选词为  argued 评分为： -25.28885691038303
# 第 47 句：
# 候选词集合 {'international': -25.28885691038303}
# 错误词为 intehnational 候选词为  international 评分为： -25.28885691038303
# 第 48 句：
# 候选词集合 {'worlds': -25.28885451082774}
# 错误词为 world's 候选词为  worlds 评分为： -25.28885451082774
# 第 49 句：
# 候选词集合 {'markets': -25.28885691038303}
# 错误词为 markats 候选词为  markets 评分为： -25.28885691038303
# 第 50 句：
# 候选词集合 {'3000': -25.28885691038303, '3500': -25.28885691038303, '5000': -25.28885691038303}
# 错误词为 530500 候选词为  3000 评分为： -25.28885691038303
# 第 50 句：
# 候选词集合 {'against': -25.28885691038303}
# 错误词为 aiagnst 候选词为  against 评分为： -25.28885691038303
# 第 50 句：
# 没有合适的修改词
# 第 51 句：
# 候选词集合 {'movement': -25.288851478842417}
# 错误词为 movament 候选词为  movement 评分为： -25.288851478842417
# 第 52 句：
# 候选词集合 {'foray': -25.28885691038303, 'dots': -25.28885691038303, 'rotary': -25.28885691038303, 'dot': -25.28885691038303, 'okay': -25.28885691038303, 'today': -25.28885691038303, 'hotly': -25.28885691038303, 'delay': -25.28885691038303, 'duty': -25.28885691038303, 'stay': -25.28885691038303, 'iota': -25.28885691038303, 'decay': -25.28885691038303, 'day': -25.28885691038303, 'dowry': -25.28885691038303, 'total': -25.28885691038303, 'data': -25.28885691038303, 'botany': -25.28885691038303, 'doan': -25.28885691038303, 'ditty': -25.28885691038303}
# 错误词为 dotay 候选词为  foray 评分为： -25.28885691038303
# 第 53 句：
# 候选词集合 {'raced': -25.28885691038303, 'ago': -25.28885691038303, 'radio': -25.288854495654967, 'rangy': -25.28885691038303, 'races': -25.28885691038303, 'race': -25.28885691038303, 'rage': -25.28885691038303, 'rancho': -25.28885691038303, 'ratio': -25.28885691038303, 'rag': -25.28885691038303, 'range': -25.28885691038303, 'rags': -25.28885691038303, 'cargo': -25.28885691038303, 'rang': -25.28885691038303, 'racy': -25.28885691038303, 'sago': -25.28885691038303, 'cacao': -25.28885691038303, 'racks': -25.28885691038303, 'facto': -25.28885691038303, 'tango': -25.288850250878088, 'rack': -25.288856314850573}
# 错误词为 racgo 候选词为  tango 评分为： -25.288850250878088
# 第 54 句：
# 候选词集合 {'Consul': -25.28885691038303, 'Council': -25.28885691038303}
# 错误词为 Coincul 候选词为  Consul 评分为： -25.28885691038303
# 第 54 句：
# 候选词集合 {'states': -25.288851478842417}
# 错误词为 state's 候选词为  states 评分为： -25.288851478842417
# 第 54 句：
# 候选词集合 {'workers': -25.28885691038303}
# 错误词为 workers' 候选词为  workers 评分为： -25.28885691038303
# 第 56 句：
# 候选词集合 {'affected': -25.28885691038303}
# 错误词为 affecced 候选词为  affected 评分为： -25.28885691038303
# 第 57 句：
# 候选词集合 {'effect': -25.288856305114095}
# 错误词为 evfect 候选词为  effect 评分为： -25.288856305114095
# 第 58 句：
# 候选词集合 {'tobacco': -25.28885691038303}
# 错误词为 tobacoc 候选词为  tobacco 评分为： -25.28885691038303
# 第 59 句：
# 候选词集合 {'wither': -25.28885691038303, 'thee': -25.28885691038303, 'writhe': -25.28885691038303, 'rather': -25.288856311408864, 'tithes': -25.28885691038303, 'hither': -25.28885691038303, 'riches': -25.28885691038303, 'rite': -25.28885691038303, 'either': -25.288849034646297, 'lithe': -25.28885691038303, 'richer': -25.28885691038303, 'rites': -25.28885691038303, 'writhed': -25.28885691038303, 'withes': -25.28885691038303}
# 错误词为 rithee 候选词为  either 评分为： -25.288849034646297
# 第 60 句：
# 候选词集合 {'being': -25.288853272349172, 'beg': -25.28885691038303, 'bent': -25.28885691038303, 'bang': -25.28885691038303, 'bend': -25.28885691038303}
# 错误词为 beng 候选词为  being 评分为： -25.288853272349172
# 第 61 句：
# 候选词集合 {'rubbed': -25.28885691038303, 'rubies': -25.28885691038303, 'rubber': -25.28885691038303}
# 错误词为 rubbes 候选词为  rubbed 评分为： -25.28885691038303
# 第 62 句：
# 候选词集合 {'cautiously': -25.28885691038303, 'cautious': -25.28885691038303}
# 错误词为 cautiousy 候选词为  cautiously 评分为： -25.28885691038303
# 第 63 句：
# 候选词集合 {'sadly': -25.288854496893165, 'safely': -15.74083075271997}
# 错误词为 safly 候选词为  safely 评分为： -15.74083075271997
# 第 64 句：
# 候选词集合 {'Physical': -25.28885691038303}
# 错误词为 Physicay 候选词为  Physical 评分为： -25.28885691038303
# 第 66 句：
# 候选词集合 {'Robusta': -25.28885691038303}
# 错误词为 Rtbusoa 候选词为  Robusta 评分为： -25.28885691038303
# 第 67 句：
# 候选词集合 {'rubber': -25.28885691038303, 'ruler': -25.28885691038303}
# 错误词为 rubebr 候选词为  rubber 评分为： -25.28885691038303
# 第 68 句：
# 候选词集合 {'aft': -25.28885691038303, 'after': -25.288852665742507, 'ate': -25.28885691038303, 'ante': -25.28885691038303}
# 错误词为 afte 候选词为  after 评分为： -25.288852665742507
# 第 68 句：
# 候选词集合 {'Indonesia': -25.28885691038303, 'Indonesian': -25.28885691038303}
# 错误词为 Indonesia's 候选词为  Indonesia 评分为： -25.28885691038303
# 第 69 句：
# 候选词集合 {'Salk': -25.28885691038303, 'Salu': -25.28885691038303, 'Salt': -25.28885691038303, 'Saleh': -25.28885691038303}
# 错误词为 Salh 候选词为  Salk 评分为： -25.28885691038303
# 第 69 句：
# 候选词集合 {'worlds': -25.28885451082774}
# 错误词为 world's 候选词为  worlds 评分为： -25.28885451082774
# 第 70 句：
# 候选词集合 {'Nainggolan': -25.28885691038303}
# 错误词为 Nannggolai 候选词为  Nainggolan 评分为： -25.28885691038303
# 第 71 句：
# 候选词集合 {'American': -25.28885691038303}
# 错误词为 Amerrican 候选词为  American 评分为： -25.28885691038303
# 第 72 句：
# 候选词集合 {'although': -25.28885691038303}
# 错误词为 althlugh 候选词为  although 评分为： -25.28885691038303
# 第 73 句：
# 候选词集合 {'99': -25.28885691038303, '95': -25.28885691038303, '55': -25.28885691038303, '59': -25.28885691038303}
# 错误词为 9595 候选词为  99 评分为： -25.28885691038303
# 第 73 句：
# 候选词集合 {'locally': -25.28885691038303, 'locale': -25.28885691038303, 'local': -25.28885691038303}
# 错误词为 locayll 候选词为  locally 评分为： -25.28885691038303
# 第 74 句：
# 候选词集合 {'87': -25.288856305680284, '68': -25.28885691038303, '67': -25.28885691038303}
# 错误词为 687 候选词为  87 评分为： -25.288856305680284
# 第 74 句：
# 候选词集合 {'billion': -25.28885691038303}
# 错误词为 bilion 候选词为  billion 评分为： -25.28885691038303
# 第 75 句：
# 候选词集合 {'brokers': -25.28885691038303}
# 错误词为 broers 候选词为  brokers 评分为： -25.28885691038303
# 第 76 句：
# 候选词集合 {'shipment': -25.28885691038303}
# 错误词为 shepment 候选词为  shipment 评分为： -25.28885691038303
# 第 77 句：
# 候选词集合 {'We': -25.28885691038303, 'Wu': -25.28885691038303}
# 错误词为 WR 候选词为  We 评分为： -25.28885691038303
# 第 77 句：
# 没有合适的修改词
# 第 78 句：
# 候选词集合 {'River': -25.28885691038303}
# 错误词为 Rivir 候选词为  River 评分为： -25.28885691038303
# 第 79 句：
# 候选词集合 {'product': -25.28885691038303, 'produce': -25.28884479333429}
# 错误词为 produc 候选词为  produce 评分为： -25.28884479333429
# 第 79 句：
# 候选词集合 {'5000': -25.28885691038303}
# 错误词为 50000 候选词为  5000 评分为： -25.28885691038303
# 第 80 句：
# 候选词集合 {'about': -25.288845997353164}
# 错误词为 abouct 候选词为  about 评分为： -25.288845997353164
# 第 80 句：
# 候选词集合 {'5000': -25.28885691038303}
# 错误词为 750000 候选词为  5000 评分为： -25.28885691038303
# 第 81 句：
# 候选词集合 {'29': -25.28885691038303, '12a': -25.28885691038303, '12': -25.28885691038303, '19': -25.28885691038303}
# 错误词为 129 候选词为  29 评分为： -25.28885691038303
# 第 81 句：
# 候选词集合 {'loans': -25.28885691038303}
# 错误词为 lovans 候选词为  loans 评分为： -25.28885691038303
# 第 82 句：
# 候选词集合 {'Reuther': -25.28885691038303, 'Reuter': -25.28885691038303, 'Reuters': -25.28885691038303}
# 错误词为 Reutres 候选词为  Reuther 评分为： -25.28885691038303
# 第 83 句：
# 候选词集合 {'Well': -25.28885691038303}
# 错误词为 We'll 候选词为  Well 评分为： -25.28885691038303
# 第 83 句：
# 候选词集合 {'interview': -25.288854486742594}
# 错误词为 inserview 候选词为  interview 评分为： -25.288854486742594
# 第 84 句：
# 候选词集合 {'wife': -25.288855703003122, 'wield': -25.28885691038303, 'mile': -25.28885691038303, 'willy': -25.28885691038303, 'wilt': -25.28885691038303, 'litle': -25.28885691038303, 'fille': -25.28885691038303, 'wide': -25.28885630940202, 'wine': -25.28885691038303, 'will': -25.28878354415904, 'bile': -25.28885691038303, 'sidle': -25.28885691038303, 'wise': -25.28885691038303, 'rifle': -25.28885691038303, 'title': -25.288853277411185, 'while': -25.288848426244964, 'pile': -25.28885691038303, 'wills': -25.28885691038303, 'wipe': -25.28885691038303, 'file': -25.28885691038303, 'tile': -25.28885691038303, 'whole': -25.288853883808617, 'willed': -25.28885691038303, 'whoe': -25.28885691038303, 'wire': -25.28885691038303, 'wild': -25.28885691038303, 'vile': -25.28885691038303, 'idle': -25.28885691038303, 'wily': -25.28885691038303, 'aisle': -25.28885691038303, 'wiggle': -25.28885691038303, 'isle': -25.28885691038303, 'wiles': -25.28885691038303, 'wil': -25.28885691038303}
# 错误词为 wihle 候选词为  will 评分为： -25.28878354415904
# 第 84 句：
# 候选词集合 {'Sumitomo': -25.28885691038303}
# 错误词为 Sumitomo's 候选词为  Sumitomo 评分为： -25.28885691038303
# 第 84 句：
# 候选词集合 {'Sumitomo': -25.28885691038303}
# 错误词为 Sumitomo's 候选词为  Sumitomo 评分为： -25.28885691038303
# 第 85 句：
# 候选词集合 {'quickly': -25.28885509170249}
# 错误词为 cuiqkly 候选词为  quickly 评分为： -25.28885509170249
# 第 86 句：
# 候选词集合 {'Sumitomo': -25.28885691038303}
# 错误词为 Somitumo 候选词为  Sumitomo 评分为： -25.28885691038303
# 第 86 句：
# 候选词集合 {'banks': -25.28885691038303}
# 错误词为 bank's 候选词为  banks 评分为： -25.28885691038303
# 第 87 句：
# 候选词集合 {'comparable': -25.28885691038303}
# 错误词为 conparable 候选词为  comparable 评分为： -25.28885691038303
# 第 88 句：
# 候选词集合 {'deer': -25.28885691038303, 'agree': -25.28885691038303, 'agreed': -25.28885691038303, 'agrees': -25.28885691038303}
# 错误词为 agdeer 候选词为  deer 评分为： -25.28885691038303
# 第 89 句：
# 候选词集合 {'overseas': -25.28885691038303, 'overeat': -25.28885691038303}
# 错误词为 ovesreas 候选词为  overseas 评分为： -25.28885691038303
# 第 90 句：
# 没有合适的修改词
# 第 90 句：
# 候选词集合 {'plane': -25.28885691038303, 'plate': -25.28885691038303, 'place': -25.288844789892586, 'play': -25.28885691038303, 'plan': -25.28885691038303}
# 错误词为 plae 候选词为  place 评分为： -25.288844789892586
# 第 91 句：
# 候选词集合 {'its': -25.28885691038303}
# 错误词为 it's 候选词为  its 评分为： -25.28885691038303
# 第 91 句：
# 候选词集合 {'Kleinwort': -25.28885691038303}
# 错误词为 Klieinwort 候选词为  Kleinwort 评分为： -25.28885691038303
# 第 92 句：
# 候选词集合 {'Sumitomo': -25.28885691038303}
# 错误词为 Sumitomo's 候选词为  Sumitomo 评分为： -25.28885691038303
# 第 92 句：
# 候选词集合 {'increase': -25.28885691038303, 'crease': -25.28885691038303}
# 错误词为 icrease 候选词为  increase 评分为： -25.28885691038303
# 第 93 句：
# 候选词集合 {'Sumitomo': -25.28885691038303}
# 错误词为 Suoitomm 候选词为  Sumitomo 评分为： -25.28885691038303
# 第 94 句：
# 候选词集合 {'Komatsu': -25.28885691038303}
# 错误词为 Kmatsu 候选词为  Komatsu 评分为： -25.28885691038303
# 第 95 句：
# 候选词集合 {'viscous': -25.28885691038303, 'vicious': -25.28885691038303, 'virtuous': -25.28885691038303, 'various': -25.28885691038303, 'virus': -25.28885691038303}
# 错误词为 viraous 候选词为  viscous 评分为： -25.28885691038303
# 第 96 句：
# 候选词集合 {'three': -25.28885206027029}
# 错误词为 thtree 候选词为  three 评分为： -25.28885206027029
# 第 97 句：
# 候选词集合 {'securities': -25.28885691038303}
# 错误词为 recusities 候选词为  securities 评分为： -25.28885691038303
# 第 98 句：
# 没有合适的修改词
# 第 99 句：
# 候选词集合 {'Komatsu': -25.28885691038303}
# 错误词为 Kmatsu 候选词为  Komatsu 评分为： -25.28885691038303
# 第 100 句：
# 候选词集合 {'business': -25.28885691038303}
# 错误词为 businiss 候选词为  business 评分为： -25.28885691038303
